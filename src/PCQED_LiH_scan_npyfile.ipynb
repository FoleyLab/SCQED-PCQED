# %%
# import libraries
import numpy as np
import sys
import psi4
from helper_PFCI import PFHamiltonianGenerator
np.set_printoptions(threshold=sys.maxsize)
psi4.core.set_output_file('output.dat', False)
import time
import json
import matplotlib.pyplot as plt
import json
import os

# %%
# !!! Change this to the correct path on your computer!
npy_folder = "/Users/rmandern/code/SCQED-PCQED/LiH_data/"

# these file names should still be good
E_npy_file = npy_folder + "PCQED_250Nel_2Np_pes.npy"

# store energy eigenvalues in E_array
E_array = np.load(E_npy_file)

# print their shape so we know how many elements we have
print(np.shape(E_array))
# Out:
# (751, 50)

# %%
print(E_array[0,:])
# Out:
# [0.5        0.54081633 0.58163265 0.62244898 0.66326531 0.70408163
#  0.74489796 0.78571429 0.82653061 0.86734694 0.90816327 0.94897959
#  0.98979592 1.03061224 1.07142857 1.1122449  1.15306122 1.19387755
#  1.23469388 1.2755102  1.31632653 1.35714286 1.39795918 1.43877551
#  1.47959184 1.52040816 1.56122449 1.60204082 1.64285714 1.68367347
#  1.7244898  1.76530612 1.80612245 1.84693878 1.8877551  1.92857143
#  1.96938776 2.01020408 2.05102041 2.09183673 2.13265306 2.17346939
#  2.21428571 2.25510204 2.29591837 2.33673469 2.37755102 2.41836735
#  2.45918367 2.5       ]

# %%
from matplotlib import pyplot as plt
from matplotlib import cm
from matplotlib import rcParams
from mpl_toolkits.mplot3d import Axes3D

# %%
plt.plot(E_array[0,:], E_array[1,:],color='r',marker="s", ms="4",linewidth=1.5, label="pPF(250,2)")
# plt.plot(E_array[0,:],E_array[2,:], color='b', marker="s", ms="4",linewidth=1.5, label='PN-pPF(500,2)')
# plt.plot(E_array[0,:],E_array[5,:])
         
plt.xlabel("Bondlength (Angstroms)")
plt.ylabel("Energy (Hartrees)")
# plt.xlim(1.4, 2.2)
# plt.ylim(-7.9970, -7.9966)
rcParams['font.family'] = 'serif'
rcParams['font.size'] = 12
plt.gca().yaxis.set_major_formatter('{:.3f}'.format)
plt.legend()
plt.tight_layout()
plt.savefig("LiH.png", dpi=150)
plt.show()
