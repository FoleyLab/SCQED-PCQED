# %%
import matplotlib.pyplot as plt

# %%
Photons = [2,4,6,8,10,20,30]
Time5_qedci = [79.455705,214.399443,383.895075,715.926843,1254.102134,2940.663590,10068.138696]
Time_10qedci = [636.504037,1177.124487,948.568115,1241.324847,1642.267704,5411.969271,11974.473645]
Time_20qedci = [665.813260,2005.644863,4561.027798,]
# Time_5CI = [84.742192,225.278872, 383.895075, 715.926843,1254.102134,10713.998956]
# Time_20CI = [1142.443919, 2665.967218,]
# Time_30CI = [2102.189317]
# Time_50CI = []
# Time_60CI = []
# Time_70CI = []

# %%
plt.plot(Photons,Time5_qedci, 'ko-',label = 'Time vs 5CI roots')
plt.plot(Photons,Time_10qedci, 'bo-',label = 'Time vs 10CI roots')
plt.savefig("T_vs_CI.png", dpi=150)
plt.legend()
plt.xlabel('CI roots')
plt.ylabel('Time(Sec)')
plt.show()

# %%
# 20p = 599.628712 sec 
No_of_roots = [5,10,20, 30, 50, 100, 150, 200]
Time = [76.543263, 180.856575, 492.668892,806.524400, 319.076603, 919.238972, 2867.957741,3875.399975]
plt.plot(No_of_roots,Time, 'ko-',label = 'Time vs CI roots')
plt.savefig("T_vs_CI.png", dpi=150)
plt.legend()
plt.xlabel('CI roots')
plt.ylabel('Time(Sec)')
plt.show()

# %%
plt.plot(No_of_photons1,Time_5CI,'bo-',marker ='*', label = '5CI')
plt.plot(No_of_photons2,Time_10CI, label = '10CI')
# plt.plot(No_of_photons,Time_20CI, label = '20CI')
rcParams['font.family'] = 'serif'
rcParams['font.size'] = 12
plt.legend()
plt.tight_layout()
plt.savefig("T_vs_P.png", dpi=150)
plt.xlabel('Number of Photons')
plt.ylabel('Time(Sec)')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 plt.plot(No_of_photons1,Time_5CI,'bo-',marker ='*', label = '5CI')
#       2 plt.plot(No_of_photons2,Time_10CI, label = '10CI')
#       3 # plt.plot(No_of_photons,Time_20CI, label = '20CI')
#
# NameError: name 'No_of_photons1' is not defined

# %%
#New data

FCI_roots = [5,10,20,30,50,100, 150, 200] 
Time_FCI = [11.211843,23.677418,88.650883,164.558595,319.505606,919.238972, 2867.957741,3875.399975]
plt.plot(FCI_roots,Time_FCI, 'ko-',label = 'Time vs CI roots')
plt.savefig("T_vs_CI.png", dpi=150)
plt.legend()
plt.xlabel('CI roots')
plt.ylabel('Time(Sec)')
plt.show()
