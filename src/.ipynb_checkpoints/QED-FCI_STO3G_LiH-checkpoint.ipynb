# %%
# import libraries
import numpy as np
import sys
import psi4
from helper_PFCI import PFHamiltonianGenerator
np.set_printoptions(threshold=sys.maxsize)
#psi4.core.set_output_file('output.dat', False)
import time

# %%
# setup basic arguments for qed-ci calculation

# z-matrix for LIH
mol_str = """
Li
H 1 1.8
symmetry c1
"""

# options for Psi4
options_dict = {
    "basis": "sto-3g",
    "scf_type": "pk",
    "e_convergence": 1e-10,
    "d_convergence": 1e-10,
}

# options for the PFHamiltonian Generator class - include cavity effects
cavity_dict = {
    'omega_value' : 0.12086,
    'lambda_vector' : np.array([0, 0, 0.05]),
    'ci_level' : 'fci',   
    'full_diagonalization' : True,
    'number_of_photons' : 1, #<== this is a minimal photon basis, should explore increasing this 
}

# options for PFHamiltonian Generator class - exclude cavity effects
cavity_free_dict = {
    'omega_value' : 0.0,
    'lambda_vector' : np.array([0, 0, 0.0]),
    'ci_level' : 'fci',   
    'full_diagonalization' : True,
    'number_of_photons' : 0, 
}

# %%
# template for the z-matrix so we can scan through bond lengths
mol_tmpl = """
Li
H 1 **R**
symmetry c1
"""


# number of bondlengths in the scan
N_R = 50

# number of electronic states to save
N_el = 10

r_array = np.linspace(1.0, 4.0, N_R)

# array for energies for LiH outside cavity
cavity_free_E_array = np.zeros((N_R, N_el))

# array  for energies inside the cavity
cavity_E_array = np.zeros((N_R, N_el))

r_idx = 0
for r in r_array:
    mol_str = mol_tmpl.replace("**R**", str(r))
    mol = psi4.geometry(mol_str)
    print(mol_str)
    
    # call psi4 RHF
    scf_e, wfn = psi4.energy('SCF/sto-3g', return_wfn=True)
    
    # call psi4 FCI
    fci_energy = psi4.energy('fci/sto-3g',ref_wfn=wfn)
    
    # LiH no cavity
    LiH = PFHamiltonianGenerator(mol_str, options_dict, cavity_free_dict)

    # check to make sure PFHamiltonian cavity-free FCI ground-state agrees with psi4
    assert np.isclose(LiH.CIeigs[0], fci_energy)
    
    # LiH with cavity
    LiH_cav = PFHamiltonianGenerator(mol_str, options_dict, cavity_dict)
    cavity_free_E_array[r_idx,:] = LiH.CIeigs[:N_el]
    cavity_E_array[r_idx,:] = LiH_cav.CIeigs[:N_el]
    r_idx += 1
# Out:
# Li
# H 1 1.0
# symmetry c1
#
#
# Scratch directory: /tmp/
#    => Libint2 <=
#
#     Primary   basis highest AM E, G, H:  5, 4, 3
#     Auxiliary basis highest AM E, G, H:  6, 5, 4
#     Onebody   basis highest AM E, G, H:  6, 5, 4
#     Solid Harmonics ordering:            gaussian
#
# *** tstart() called on CHEMYM0V4HTALT
# *** at Thu Oct 12 13:51:30 2023
#
#    => Loading Basis Set <=
#
#     Name: STO-3G
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1 entry LI         line    31 file /Users/ptolley1/miniforge3/envs/work/share/psi4/basis/sto-3g.gbs
#     atoms 2 entry H          line    19 file /Users/ptolley1/miniforge3/envs/work/share/psi4/basis/sto-3g.gbs
#
#
#          ---------------------------------------------------------
#                                    SCF
#                by Justin Turney, Rob Parrish, Andy Simmonett
#                           and Daniel G. A. Smith
#                               RHF Reference
#                         1 Threads,    500 MiB Core
#          ---------------------------------------------------------
#
#   ==> Geometry <==
#
#     Molecular point group: c1
#     Full point group: C_inf_v
#
#     Geometry (in Angstrom), charge = 0, multiplicity = 1:
#
#        Center              X                  Y                   Z               Mass
#     ------------   -----------------  -----------------  -----------------  -----------------
#          LI           0.000000000000     0.000000000000    -0.125604010124     7.016003436600
#          H            0.000000000000     0.000000000000     0.874395989876     1.007825032230
#
#   Running in c1 symmetry.
#
#   Rotational constants: A = ************  B =     19.12948  C =     19.12948 [cm^-1]
#   Rotational constants: A = ************  B = 573487.42707  C = 573487.42707 [MHz]
#   Nuclear repulsion =    1.587531632010000
#
#   Charge       = 0
#   Multiplicity = 1
#   Electrons    = 4
#   Nalpha       = 2
#   Nbeta        = 2
#
#   ==> Algorithm <==
#
#   SCF Algorithm Type is PK.
#   DIIS enabled.
#   MOM disabled.
#   Fractional occupation disabled.
#   Guess Type is SAD.
#   Energy threshold   = 1.00e-08
#   Density threshold  = 1.00e-07
#   Integral threshold = 1.00e-12
#
#   ==> Primary Basis <==
#
#   Basis Set: STO-3G
#     Blend: STO-3G
#     Number of shells: 4
#     Number of basis functions: 6
#     Number of Cartesian functions: 6
#     Spherical Harmonics?: true
#     Max angular momentum: 1
#
#   ==> Integral Setup <==
#
#   Using in-core PK algorithm.
#    Calculation information:
#       Number of atoms:                   2
#       Number of AO shells:               4
#       Number of primitives:             12
#       Number of atomic orbitals:         6
#       Number of basis functions:         6
#
#       Integral cutoff                 1.00e-12
#       Number of threads:                 1
#
#   Performing in-core PK
#   Using 462 doubles for integral storage.
#   We computed 55 shell quartets total.
#   Whereas there are 55 unique shell quartets.
#
#   ==> DiskJK: Disk-Based J/K Matrices <==
#
#     J tasked:                  Yes
#     K tasked:                  Yes
#     wK tasked:                  No
#     Memory [MiB]:              375
#     Schwarz Cutoff:          1E-12
#
#     OpenMP threads:              1
#
#   Minimum eigenvalue in the overlap matrix is 2.3092409411E-01.
#   Reciprocal condition number of the overlap matrix is 1.2400502257E-01.
#     Using symmetric orthogonalization.
#
#   ==> Pre-Iterations <==
#
#   SCF Guess: Superposition of Atomic Densities via on-the-fly atomic UHF (no occupation information).
#
#    -------------------------
#     Irrep   Nso     Nmo
#    -------------------------
#      A          6       6
#    -------------------------
#     Total       6       6
#    -------------------------
#
#   ==> Iterations <==
#
#                         Total Energy        Delta E     RMS |[F,P]|
#
#    @RHF iter SAD:    -7.51973509916564   -7.51974e+00   0.00000e+00
#    @RHF iter   1:    -7.75950898792799   -2.39774e-01   1.34793e-02 ADIIS/DIIS
#    @RHF iter   2:    -7.76719441826475   -7.68543e-03   1.32896e-03 ADIIS/DIIS
#    @RHF iter   3:    -7.76733105322056   -1.36635e-04   3.96082e-04 ADIIS/DIIS
#    @RHF iter   4:    -7.76735945450929   -2.84013e-05   1.16020e-04 ADIIS/DIIS
#    @RHF iter   5:    -7.76736213584798   -2.68134e-06   9.13154e-07 DIIS
#    @RHF iter   6:    -7.76736213598649   -1.38503e-10   4.83291e-08 DIIS
#   Energy and wave function converged.
#
#
#   ==> Post-Iterations <==
#
#     Orbital Energies [Eh]
#     ---------------------
#
#     Doubly Occupied:
#
#        1A     -2.370899     2A     -0.316657
#
#     Virtual:
#
#        3A      0.076848     4A      0.157939     5A      0.157939
#        6A      0.612999
#
#     Final Occupation by Irrep:
#               A
#     DOCC [     2 ]
#     NA   [     2 ]
#     NB   [     2 ]
#
#   @RHF Final Energy:    -7.76736213598649
#
#    => Energetics <=
#
#     Nuclear Repulsion Energy =              1.5875316320100001
#     One-Electron Energy =                 -13.3346744772943016
#     Two-Electron Energy =                   3.9797807092978137
#     Total Energy =                         -7.7673621359864882
#
# Computation Completed
#
#
# Properties will be evaluated at   0.000000,   0.000000,   0.000000 [a0]
#
# Properties computed using the SCF density matrix
#
#
#  Multipole Moments:
#
#  ------------------------------------------------------------------------------------
#      Multipole            Electronic (a.u.)      Nuclear  (a.u.)        Total (a.u.)
#  ------------------------------------------------------------------------------------
#
#  L = 1.  Multiply by 2.5417464519 to convert [e a0] to [Debye]
#  Dipole X            :          0.0000000            0.0000000            0.0000000
#  Dipole Y            :         -0.0000000            0.0000000           -0.0000000
#  Dipole Z            :         -2.8355307            0.9402974           -1.8952333
#  Magnitude           :                                                    1.8952333
#
#  ------------------------------------------------------------------------------------
#
# *** tstop() called on CHEMYM0V4HTALT at Thu Oct 12 13:51:30 2023
# Module time:
# 	user time   =       0.07 seconds =       0.00 minutes
# 	system time =       0.01 seconds =       0.00 minutes
# 	total time  =          0 seconds =       0.00 minutes
# Total time:
# 	user time   =      89.72 seconds =       1.50 minutes
# 	system time =       3.04 seconds =       0.05 minutes
# 	total time  =      80391 seconds =    1339.85 minutes
#
# Scratch directory: /tmp/
#  MINTS: Wrapper to libmints.
#    by Justin Turney
#
#    Calculation information:
#       Number of threads:                 1
#       Number of atoms:                   2
#       Number of AO shells:               4
#       Number of SO shells:               4
#       Number of primitives:             12
#       Number of atomic orbitals:         6
#       Number of basis functions:         6
#
#       Number of irreps:                  1
#       Integral cutoff                 1.00e-12
#       Number of functions per irrep: [   6 ]
#
#  OEINTS: Overlap, kinetic, potential, dipole, and quadrupole integrals
#          stored in file 35.
#
#       Computing two-electron integrals...done
#       Computed 83 non-zero two-electron integrals.
#         Stored in file 33.
#
#
#          ---------------------------------------------------------
#                           Configuration Interaction
#                             (a 'D E T C I' module)
#
#                  C. David Sherrill, Daniel G. A. Smith, and
#                               Matt L. Leininger
#          ---------------------------------------------------------
#
#
#    ==> Parameters <==
#
#     EX LEVEL       =        4      H0 BLOCKSIZE  =     1000
#     VAL EX LEVEL   =        0      H0 GUESS SIZE =     1000
#     H0COUPLINGSIZE =        0      H0 COUPLING   =       NO
#     MAXITER        =       24      NUM PRINT     =       20
#     NUM ROOTS      =        1      ICORE         =        1
#     PRINT LVL      =        1      FCI           =      YES
#     R CONV         = 1.00e-04      MIXED         =      YES
#     E CONV         = 1.00e-08      MIXED4        =      YES
#     R4S            =       NO      REPL OTF      =       NO
#     DIAG METHOD    =      SEM      FOLLOW ROOT   =        0
#     PRECONDITIONER = DAVIDSON      UPDATE        = DAVIDSON
#     S              =   0.0000      Ms0           =      YES
#     GUESS VECTOR   =  H0BLOCK      OPENTYPE      =     NONE
#     COLLAPSE SIZE  =        1      HD AVG        = EVANGELISTI
#     MAX NUM VECS   =       25      REF SYM       =     AUTO
#     IOPEN        =       NO
#
#     EX ALLOW       =  1  1  1  1
#     STATE AVERAGE  =  0(1.00)
#
#    ==> CI Orbital and Space information <==
#
#    ------------------------------------
#                Space    Total     A
#    ------------------------------------
#                  Nso        6     6
#                  Nmo        6     6
#                Ndocc        2     2
#                Nsocc        0     0
#    ------------------------------------
#               CI Spaces
#    ------------------------------------
#         Dropped DOCC        0     0
#               Active        6     6
#         Dropped UOCC        0     0
#    ------------------------------------
#
#    ==> Setting up CI strings <==
#
#     There are 15 alpha and 15 beta strings
#     The CI space requires 225 (2.25E+02) determinants and 1 blocks
#
#    ==> Transforming CI integrals <==
#
# 	Presorting SO-basis two-electron integrals.
# 	Sorting File: SO Ints (nn|nn) nbuckets = 1
# 	Constructing frozen core operators
# 	Starting first half-transformation.
# 	Sorting half-transformed integrals.
# 	First half integral transformation complete.
# 	Starting second half-transformation.
# 	Two-electron integral transformation complete.
#
#    ==> Starting CI iterations <==
#
#     H0 Block Eigenvalue =  -7.78446028
#
#     Simultaneous Expansion Method (Block Davidson Method)
#     Using 1 initial trial vectors
#
#      Iter   Root       Total Energy       Delta E      C RMS
#
#    @CI  0:     0     -7.784460280267   -9.3720E+00   3.8092E-14
#     Warning: Norm of correction (root 0) is < 1.0E-13
#    @CI  1:     0     -7.784460280267   0.0000E+00   2.9184E-13 c
#
#    ==> Energetics <==
#
#     SCF energy =           -7.767362135986488
#     Total CI energy =      -7.784460280267091
#
#    ==> FCI root 0 information <==
#
#     FCI Root 0 energy =    -7.784460280267091
#
#    The 20 most important determinants:
#
#     *   1   -0.990904  (    0,    0)  1AX 2AX
#     *   2    0.096431  (   10,   10)  1AX 6AX
#     *   3   -0.043300  (    1,   10)  1AX 3AA 6AB
#     *   4   -0.043300  (   10,    1)  1AX 3AB 6AA
#     *   5    0.036316  (    3,    3)  1AX 4AX
#     *   6    0.036316  (    6,    6)  1AX 5AX
#     *   7   -0.030232  (    0,    1)  1AX 2AA 3AB
#     *   8   -0.030232  (    1,    0)  1AX 2AB 3AA
#     *   9    0.021439  (    1,    1)  1AX 3AX
#     *  10   -0.004219  (    2,   10)  1AB 2AA 3AA 6AB
#     *  11   -0.004219  (   10,    2)  1AA 2AB 3AB 6AA
#     *  12    0.003343  (    2,    2)  2AX 3AX
#     *  13    0.002988  (    6,    7)  1AA 2AB 5AX
#     *  14    0.002988  (    7,    6)  1AB 2AA 5AX
#     *  15    0.002988  (    3,    4)  1AA 2AB 4AX
#     *  16    0.002988  (    4,    3)  1AB 2AA 4AX
#     *  17    0.002914  (   10,   11)  1AA 2AB 6AX
#     *  18    0.002914  (   11,   10)  1AB 2AA 6AX
#     *  19    0.002795  (    0,   12)  1AA 2AA 3AB 6AB
#     *  20    0.002795  (   12,    0)  1AB 2AB 3AA 6AA
#
# 		 "A good bug is a dead bug"
#
# 			 - Starship Troopers
#
# 		 "I didn't write FORTRAN.  That's the problem."
#
# 			 - Edward Valeev
#
# Scratch directory: /tmp/
#    => Libint2 <=
#
#     Primary   basis highest AM E, G, H:  5, 4, 3
#     Auxiliary basis highest AM E, G, H:  6, 5, 4
#     Onebody   basis highest AM E, G, H:  6, 5, 4
#     Solid Harmonics ordering:            gaussian
#
# *** tstart() called on CHEMYM0V4HTALT
# *** at Thu Oct 12 13:51:30 2023
#
#    => Loading Basis Set <=
#
#     Name: STO-3G
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1 entry LI         line    31 file /Users/ptolley1/miniforge3/envs/work/share/psi4/basis/sto-3g.gbs
#     atoms 2 entry H          line    19 file /Users/ptolley1/miniforge3/envs/work/share/psi4/basis/sto-3g.gbs
#
#
#          ---------------------------------------------------------
#                                    SCF
#                by Justin Turney, Rob Parrish, Andy Simmonett
#                           and Daniel G. A. Smith
#                               RHF Reference
#                         1 Threads,    500 MiB Core
#          ---------------------------------------------------------
#
#   ==> Geometry <==
#
#     Molecular point group: c1
#     Full point group: C_inf_v
#
#     Geometry (in Angstrom), charge = 0, multiplicity = 1:
#
#        Center              X                  Y                   Z               Mass
#     ------------   -----------------  -----------------  -----------------  -----------------
#          LI           0.000000000000     0.000000000000    -0.125604010124     7.016003436600
#          H            0.000000000000     0.000000000000     0.874395989876     1.007825032230
#
#   Running in c1 symmetry.
#
#   Rotational constants: A = ************  B =     19.12948  C =     19.12948 [cm^-1]
#   Rotational constants: A = ************  B = 573487.42707  C = 573487.42707 [MHz]
#   Nuclear repulsion =    1.587531632010000
#
#   Charge       = 0
#   Multiplicity = 1
#   Electrons    = 4
#   Nalpha       = 2
#   Nbeta        = 2
#
#   ==> Algorithm <==
#
#   SCF Algorithm Type is PK.
#   DIIS enabled.
#   MOM disabled.
#   Fractional occupation disabled.
#   Guess Type is SAD.
#   Energy threshold   = 1.00e-10
#   Density threshold  = 1.00e-10
#   Integral threshold = 1.00e-12
#
#   ==> Primary Basis <==
#
#   Basis Set: STO-3G
#     Blend: STO-3G
#     Number of shells: 4
#     Number of basis functions: 6
#     Number of Cartesian functions: 6
#     Spherical Harmonics?: true
#     Max angular momentum: 1
#
#   ==> Integral Setup <==
#
#   Using in-core PK algorithm.
#    Calculation information:
#       Number of atoms:                   2
#       Number of AO shells:               4
#       Number of primitives:             12
#       Number of atomic orbitals:         6
#       Number of basis functions:         6
#
#       Integral cutoff                 1.00e-12
#       Number of threads:                 1
#
#   Performing in-core PK
#   Using 462 doubles for integral storage.
#   We computed 55 shell quartets total.
#   Whereas there are 55 unique shell quartets.
#
#   ==> DiskJK: Disk-Based J/K Matrices <==
#
#     J tasked:                  Yes
#     K tasked:                  Yes
#     wK tasked:                  No
#     Memory [MiB]:              375
#     Schwarz Cutoff:          1E-12
#
#     OpenMP threads:              1
#
#   Minimum eigenvalue in the overlap matrix is 2.3092409411E-01.
#   Reciprocal condition number of the overlap matrix is 1.2400502257E-01.
#     Using symmetric orthogonalization.
#
#   ==> Pre-Iterations <==
#
#   SCF Guess: Superposition of Atomic Densities via on-the-fly atomic UHF (no occupation information).
#
#    -------------------------
#     Irrep   Nso     Nmo
#    -------------------------
#      A          6       6
#    -------------------------
#     Total       6       6
#    -------------------------
#
#   ==> Iterations <==
#
#                         Total Energy        Delta E     RMS |[F,P]|
#
#    @RHF iter SAD:    -7.51973509916564   -7.51974e+00   0.00000e+00
#    @RHF iter   1:    -7.75950898792799   -2.39774e-01   1.34793e-02 ADIIS/DIIS
#    @RHF iter   2:    -7.76719441826475   -7.68543e-03   1.32896e-03 ADIIS/DIIS
#    @RHF iter   3:    -7.76733105322056   -1.36635e-04   3.96082e-04 ADIIS/DIIS
#    @RHF iter   4:    -7.76735945450929   -2.84013e-05   1.16020e-04 ADIIS/DIIS
#    @RHF iter   5:    -7.76736213584798   -2.68134e-06   9.13154e-07 DIIS
#    @RHF iter   6:    -7.76736213598649   -1.38503e-10   4.83291e-08 DIIS
#    @RHF iter   7:    -7.76736213598654   -4.97380e-14   3.34700e-10 DIIS
#    @RHF iter   8:    -7.76736213598653    7.99361e-15   5.33637e-13 DIIS
#   Energy and wave function converged.
#
#
#   ==> Post-Iterations <==
#
#     Orbital Energies [Eh]
#     ---------------------
#
#     Doubly Occupied:
#
#        1A     -2.370899     2A     -0.316657
#
#     Virtual:
#
#        3A      0.076848     4A      0.157939     5A      0.157939
#        6A      0.612999
#
#     Final Occupation by Irrep:
#               A
#     DOCC [     2 ]
#     NA   [     2 ]
#     NB   [     2 ]
#
#   @RHF Final Energy:    -7.76736213598653
#
#    => Energetics <=
#
#     Nuclear Repulsion Energy =              1.5875316320100001
#     One-Electron Energy =                 -13.3346745238238906
#     Two-Electron Energy =                   3.9797807558273606
#     Total Energy =                         -7.7673621359865299
#
# Computation Completed
#
#
# Properties will be evaluated at   0.000000,   0.000000,   0.000000 [a0]
#
# Properties computed using the SCF density matrix
#
#
#  Multipole Moments:
#
#  ------------------------------------------------------------------------------------
#      Multipole            Electronic (a.u.)      Nuclear  (a.u.)        Total (a.u.)
#  ------------------------------------------------------------------------------------
#
#  L = 1.  Multiply by 2.5417464519 to convert [e a0] to [Debye]
#  Dipole X            :          0.0000000            0.0000000            0.0000000
#  Dipole Y            :          0.0000000            0.0000000            0.0000000
#  Dipole Z            :         -2.8355307            0.9402974           -1.8952333
#  Magnitude           :                                                    1.8952333
#
#  ------------------------------------------------------------------------------------
#
# Start SCF iterations:
#
# Canonical RHF One-electron energy = -13.3346745238277453
# CQED-RHF One-electron energy      = -13.3346745238277453
# Nuclear repulsion energy          = 1.5875316320100001
# Dipole energy                     = 0.0000000000000000
#
# *** tstop() called on CHEMYM0V4HTALT at Thu Oct 12 13:51:30 2023
# Module time:
# 	user time   =       0.06 seconds =       0.00 minutes
# 	system time =       0.00 seconds =       0.00 minutes
# 	total time  =          0 seconds =       0.00 minutes
# Total time:
# 	user time   =      89.82 seconds =       1.50 minutes
# 	system time =       3.05 seconds =       0.05 minutes
# 	total time  =      80391 seconds =    1339.85 minutes
# SCF Iteration   1: Energy = -7.7673621359865361   dE = -7.76736E+00   dRMS = 2.13934E-15
# SCF Iteration   2: Energy = -7.7673621359865486   dE = -1.24345E-14   dRMS = 1.19441E-15
# Total time for SCF iterations: 0.001 seconds
#
# QED-RHF   energy: -7.76736214 hartree
# Psi4  SCF energy: -7.76736214 hartree
#  Completed QED-RHF in 0.08402204513549805 seconds
#    => Loading Basis Set <=
#
#     Name: STO-3G
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1 entry LI         line    31 file /Users/ptolley1/miniforge3/envs/work/share/psi4/basis/sto-3g.gbs
#     atoms 2 entry H          line    19 file /Users/ptolley1/miniforge3/envs/work/share/psi4/basis/sto-3g.gbs
#
#  Completed 1HSO Build in 8.487701416015625e-05 seconds
#  Completed ERI Build in 0.0011620521545410156 seconds
#  Completed 2D build in 7.605552673339844e-05 seconds
#  Completed 1G build in 1.5974044799804688e-05 seconds
#  Completed the Dipole Matrix Build in 4.1961669921875e-05 seconds
#  Completed determinant list in 0.0004942417144775391 seconds
#  Completed constant offset matrix in 0.00013899803161621094 seconds
#  Completed Hamiltonian build in 0.7064766883850098 seconds
#
# Scratch directory: /tmp/
#    => Libint2 <=
#
#     Primary   basis highest AM E, G, H:  5, 4, 3
#     Auxiliary basis highest AM E, G, H:  6, 5, 4
#     Onebody   basis highest AM E, G, H:  6, 5, 4
#     Solid Harmonics ordering:            gaussian
#
# *** tstart() called on CHEMYM0V4HTALT
# *** at Thu Oct 12 13:51:30 2023
#
#    => Loading Basis Set <=
#
#     Name: STO-3G
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1 entry LI         line    31 file /Users/ptolley1/miniforge3/envs/work/share/psi4/basis/sto-3g.gbs
#     atoms 2 entry H          line    19 file /Users/ptolley1/miniforge3/envs/work/share/psi4/basis/sto-3g.gbs
#
#
#          ---------------------------------------------------------
#                                    SCF
#                by Justin Turney, Rob Parrish, Andy Simmonett
#                           and Daniel G. A. Smith
#                               RHF Reference
#                         1 Threads,    500 MiB Core
#          ---------------------------------------------------------
#
#   ==> Geometry <==
#
#     Molecular point group: c1
#     Full point group: C_inf_v
#
#     Geometry (in Angstrom), charge = 0, multiplicity = 1:
#
#        Center              X                  Y                   Z               Mass
#     ------------   -----------------  -----------------  -----------------  -----------------
#          LI           0.000000000000     0.000000000000    -0.125604010124     7.016003436600
#          H            0.000000000000     0.000000000000     0.874395989876     1.007825032230
#
#   Running in c1 symmetry.
#
#   Rotational constants: A = ************  B =     19.12948  C =     19.12948 [cm^-1]
#   Rotational constants: A = ************  B = 573487.42707  C = 573487.42707 [MHz]
#   Nuclear repulsion =    1.587531632010000
#
#   Charge       = 0
#   Multiplicity = 1
#   Electrons    = 4
#   Nalpha       = 2
#   Nbeta        = 2
#
#   ==> Algorithm <==
#
#   SCF Algorithm Type is PK.
#   DIIS enabled.
#   MOM disabled.
#   Fractional occupation disabled.
#   Guess Type is SAD.
#   Energy threshold   = 1.00e-10
#   Density threshold  = 1.00e-10
#   Integral threshold = 1.00e-12
#
#   ==> Primary Basis <==
#
#   Basis Set: STO-3G
#     Blend: STO-3G
#     Number of shells: 4
#     Number of basis functions: 6
#     Number of Cartesian functions: 6
#     Spherical Harmonics?: true
#     Max angular momentum: 1
#
#   ==> Integral Setup <==
#
#   Using in-core PK algorithm.
#    Calculation information:
#       Number of atoms:                   2
#       Number of AO shells:               4
#       Number of primitives:             12
#       Number of atomic orbitals:         6
#       Number of basis functions:         6
#
#       Integral cutoff                 1.00e-12
#       Number of threads:                 1
#
#   Performing in-core PK
#   Using 462 doubles for integral storage.
#   We computed 55 shell quartets total.
#   Whereas there are 55 unique shell quartets.
#
#   ==> DiskJK: Disk-Based J/K Matrices <==
#
#     J tasked:                  Yes
#     K tasked:                  Yes
#     wK tasked:                  No
#     Memory [MiB]:              375
#     Schwarz Cutoff:          1E-12
#
#     OpenMP threads:              1
#
#   Minimum eigenvalue in the overlap matrix is 2.3092409411E-01.
#   Reciprocal condition number of the overlap matrix is 1.2400502257E-01.
#     Using symmetric orthogonalization.
#
#   ==> Pre-Iterations <==
#
#   SCF Guess: Superposition of Atomic Densities via on-the-fly atomic UHF (no occupation information).
#
#    -------------------------
#     Irrep   Nso     Nmo
#    -------------------------
#      A          6       6
#    -------------------------
#     Total       6       6
#    -------------------------
#
#   ==> Iterations <==
#
#                         Total Energy        Delta E     RMS |[F,P]|
#
#    @RHF iter SAD:    -7.51973509916564   -7.51974e+00   0.00000e+00
#    @RHF iter   1:    -7.75950898792799   -2.39774e-01   1.34793e-02 ADIIS/DIIS
#    @RHF iter   2:    -7.76719441826475   -7.68543e-03   1.32896e-03 ADIIS/DIIS
#    @RHF iter   3:    -7.76733105322056   -1.36635e-04   3.96082e-04 ADIIS/DIIS
#    @RHF iter   4:    -7.76735945450929   -2.84013e-05   1.16020e-04 ADIIS/DIIS
#    @RHF iter   5:    -7.76736213584798   -2.68134e-06   9.13154e-07 DIIS
#    @RHF iter   6:    -7.76736213598649   -1.38503e-10   4.83291e-08 DIIS
#    @RHF iter   7:    -7.76736213598654   -4.97380e-14   3.34700e-10 DIIS
#    @RHF iter   8:    -7.76736213598653    7.99361e-15   5.33637e-13 DIIS
#   Energy and wave function converged.
#
#
#   ==> Post-Iterations <==
#
#     Orbital Energies [Eh]
#     ---------------------
#
#     Doubly Occupied:
#
#        1A     -2.370899     2A     -0.316657
#
#     Virtual:
#
#        3A      0.076848     4A      0.157939     5A      0.157939
#        6A      0.612999
#
#     Final Occupation by Irrep:
#               A
#     DOCC [     2 ]
#     NA   [     2 ]
#     NB   [     2 ]
#
#   @RHF Final Energy:    -7.76736213598653
#
#    => Energetics <=
#
#     Nuclear Repulsion Energy =              1.5875316320100001
#     One-Electron Energy =                 -13.3346745238238906
#     Two-Electron Energy =                   3.9797807558273606
#     Total Energy =                         -7.7673621359865299
#
# Computation Completed
#
#
# Properties will be evaluated at   0.000000,   0.000000,   0.000000 [a0]
#
# Properties computed using the SCF density matrix
#
#
#  Multipole Moments:
#
#  ------------------------------------------------------------------------------------
#      Multipole            Electronic (a.u.)      Nuclear  (a.u.)        Total (a.u.)
#  ------------------------------------------------------------------------------------
#
#  L = 1.  Multiply by 2.5417464519 to convert [e a0] to [Debye]
#  Dipole X            :          0.0000000            0.0000000            0.0000000
#  Dipole Y            :          0.0000000            0.0000000            0.0000000
#  Dipole Z            :         -2.8355307            0.9402974           -1.8952333
#  Magnitude           :                                                    1.8952333
#
#  ------------------------------------------------------------------------------------
#
# Start SCF iterations:
#
# Canonical RHF One-electron energy = -13.3346745238277453
# CQED-RHF One-electron energy      = -13.3241454366046632
# Nuclear repulsion energy          = 1.5875316320100001
# Dipole energy                     = 0.0100502927109982
#
# *** tstop() called on CHEMYM0V4HTALT at Thu Oct 12 13:51:31 2023
# Module time:
# 	user time   =       0.06 seconds =       0.00 minutes
# 	system time =       0.00 seconds =       0.00 minutes
# 	total time  =          1 seconds =       0.02 minutes
# Total time:
# 	user time   =      90.62 seconds =       1.51 minutes
# 	system time =       3.07 seconds =       0.05 minutes
# 	total time  =      80392 seconds =    1339.87 minutes
# SCF Iteration   1: Energy = -7.7639405850266083   dE = -7.76394E+00   dRMS = 4.20589E-04
# SCF Iteration   2: Energy = -7.7639495413056832   dE = -8.95628E-06   dRMS = 9.34521E-05
# SCF Iteration   3: Energy = -7.7639506320569023   dE = -1.09075E-06   dRMS = 3.37061E-05
# SCF Iteration   4: Energy = -7.7639508446300276   dE = -2.12573E-07   dRMS = 2.91014E-06
# SCF Iteration   5: Energy = -7.7639508455879618   dE = -9.57934E-10   dRMS = 1.03264E-08
# SCF Iteration   6: Energy = -7.7639508455879742   dE = -1.24345E-14   dRMS = 7.94202E-10
# SCF Iteration   7: Energy = -7.7639508455879707   dE =  3.55271E-15   dRMS = 4.54232E-13
# Total time for SCF iterations: 0.001 seconds
#
# QED-RHF   energy: -7.76395085 hartree
# Psi4  SCF energy: -7.76736214 hartree
#  Completed QED-RHF in 0.08646106719970703 seconds
#  Completed 1HSO Build in 6.103515625e-05 seconds
#  Completed ERI Build in 0.0011489391326904297 seconds
#    => Loading Basis Set <=
#
#     Name: STO-3G
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1 entry LI         line    31 file /Users/ptolley1/miniforge3/envs/work/share/psi4/basis/sto-3g.gbs
#     atoms 2 entry H          line    19 file /Users/ptolley1/miniforge3/envs/work/share/psi4/basis/sto-3g.gbs
#
#  Completed 2D build in 0.00014090538024902344 seconds
#  Completed 1G build in 2.4080276489257812e-05 seconds
#  Completed the Dipole Matrix Build in 5.0067901611328125e-05 seconds
#  Completed determinant list in 0.0004353523254394531 seconds
#  Completed constant offset matrix in 0.00012969970703125 seconds
#  Completed Hamiltonian build in 0.7033960819244385 seconds
#
# Li
# H 1 1.0612244897959184
# symmetry c1
#
#
# Scratch directory: /tmp/
#    => Libint2 <=
#
#     Primary   basis highest AM E, G, H:  5, 4, 3
#     Auxiliary basis highest AM E, G, H:  6, 5, 4
#     Onebody   basis highest AM E, G, H:  6, 5, 4
#     Solid Harmonics ordering:            gaussian
#
# *** tstart() called on CHEMYM0V4HTALT
# *** at Thu Oct 12 13:51:31 2023
#
#    => Loading Basis Set <=
#
#     Name: STO-3G
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1 entry LI         line    31 file /Users/ptolley1/miniforge3/envs/work/share/psi4/basis/sto-3g.gbs
#     atoms 2 entry H          line    19 file /Users/ptolley1/miniforge3/envs/work/share/psi4/basis/sto-3g.gbs
#
#
#          ---------------------------------------------------------
#                                    SCF
#                by Justin Turney, Rob Parrish, Andy Simmonett
#                           and Daniel G. A. Smith
#                               RHF Reference
#                         1 Threads,    500 MiB Core
#          ---------------------------------------------------------
#
#   ==> Geometry <==
#
#     Molecular point group: c1
#     Full point group: C_inf_v
#
#     Geometry (in Angstrom), charge = 0, multiplicity = 1:
#
#        Center              X                  Y                   Z               Mass
#     ------------   -----------------  -----------------  -----------------  -----------------
#          LI           0.000000000000     0.000000000000    -0.133294051560     7.016003436600
#          H            0.000000000000     0.000000000000     0.927930438236     1.007825032230
#
#   Running in c1 symmetry.
#
#   Rotational constants: A = ************  B =     16.98590  C =     16.98590 [cm^-1]
#   Rotational constants: A = ************  B = 509224.59778  C = 509224.59778 [MHz]
#   Nuclear repulsion =    1.495943268624808
#
#   Charge       = 0
#   Multiplicity = 1
#   Electrons    = 4
#   Nalpha       = 2
#   Nbeta        = 2
#
#   ==> Algorithm <==
#
#   SCF Algorithm Type is PK.
#   DIIS enabled.
#   MOM disabled.
#   Fractional occupation disabled.
#   Guess Type is SAD.
#   Energy threshold   = 1.00e-10
#   Density threshold  = 1.00e-10
#   Integral threshold = 1.00e-12
#
#   ==> Primary Basis <==
#
#   Basis Set: STO-3G
#     Blend: STO-3G
#     Number of shells: 4
#     Number of basis functions: 6
#     Number of Cartesian functions: 6
#     Spherical Harmonics?: true
#     Max angular momentum: 1
#
#   ==> Integral Setup <==
#
#   Using in-core PK algorithm.
#    Calculation information:
#       Number of atoms:                   2
#       Number of AO shells:               4
#       Number of primitives:             12
#       Number of atomic orbitals:         6
#       Number of basis functions:         6
#
#       Integral cutoff                 1.00e-12
#       Number of threads:                 1
#
#   Performing in-core PK
#   Using 462 doubles for integral storage.
#   We computed 55 shell quartets total.
#   Whereas there are 55 unique shell quartets.
#
#   ==> DiskJK: Disk-Based J/K Matrices <==
#
#     J tasked:                  Yes
#     K tasked:                  Yes
#     wK tasked:                  No
#     Memory [MiB]:              375
#     Schwarz Cutoff:          1E-12
#
#     OpenMP threads:              1
#
#   Minimum eigenvalue in the overlap matrix is 2.3698916242E-01.
#   Reciprocal condition number of the overlap matrix is 1.2837061490E-01.
#     Using symmetric orthogonalization.
#
#   ==> Pre-Iterations <==
#
#   SCF Guess: Superposition of Atomic Densities via on-the-fly atomic UHF (no occupation information).
#
#    -------------------------
#     Irrep   Nso     Nmo
#    -------------------------
#      A          6       6
#    -------------------------
#     Total       6       6
#    -------------------------
#
#   ==> Iterations <==
#
#                         Total Energy        Delta E     RMS |[F,P]|
#
#    @RHF iter SAD:    -7.50772226593164   -7.50772e+00   0.00000e+00
#    @RHF iter   1:    -7.78566097647494   -2.77939e-01   1.42811e-02 ADIIS/DIIS
#    @RHF iter   2:    -7.79448531518342   -8.82434e-03   1.44310e-03 ADIIS/DIIS
#    @RHF iter   3:    -7.79465198710412   -1.66672e-04   4.31379e-04 ADIIS/DIIS
#    @RHF iter   4:    -7.79468632784678   -3.43407e-05   1.02659e-04 ADIIS/DIIS
#    @RHF iter   5:    -7.79468832986357   -2.00202e-06   9.08704e-07 DIIS
#    @RHF iter   6:    -7.79468833002843   -1.64858e-10   1.85027e-08 DIIS
#    @RHF iter   7:    -7.79468833002843   -7.10543e-15   5.79995e-10 DIIS
#    @RHF iter   8:    -7.79468833002843    2.66454e-15   9.09516e-12 DIIS
#   Energy and wave function converged.
#
#
#   ==> Post-Iterations <==
#
#     Orbital Energies [Eh]
#     ---------------------
#
#     Doubly Occupied:
#
#        1A     -2.361472     2A     -0.316699
#
#     Virtual:
#
#        3A      0.078047     4A      0.159303     5A      0.159303
#        6A      0.618872
#
#     Final Occupation by Irrep:
#               A
#     DOCC [     2 ]
#     NA   [     2 ]
#     NB   [     2 ]
#
#   @RHF Final Energy:    -7.79468833002843
#
#    => Energetics <=
#
#     Nuclear Repulsion Energy =              1.4959432686248075
#     One-Electron Energy =                 -13.2249202948479674
#     Two-Electron Energy =                   3.9342886961947277
#     Total Energy =                         -7.7946883300284320
#
# Computation Completed
#
#
# Properties will be evaluated at   0.000000,   0.000000,   0.000000 [a0]
#
# Properties computed using the SCF density matrix
#
#
#  Multipole Moments:
#
#  ------------------------------------------------------------------------------------
#      Multipole            Electronic (a.u.)      Nuclear  (a.u.)        Total (a.u.)
#  ------------------------------------------------------------------------------------
#
#  L = 1.  Multiply by 2.5417464519 to convert [e a0] to [Debye]
#  Dipole X            :         -0.0000000            0.0000000           -0.0000000
#  Dipole Y            :          0.0000000            0.0000000            0.0000000
#  Dipole Z            :         -2.8908566            0.9978666           -1.8929899
#  Magnitude           :                                                    1.8929899
#
#  ------------------------------------------------------------------------------------
#
# *** tstop() called on CHEMYM0V4HTALT at Thu Oct 12 13:51:31 2023
# Module time:
# 	user time   =       0.06 seconds =       0.00 minutes
# 	system time =       0.00 seconds =       0.00 minutes
# 	total time  =          0 seconds =       0.00 minutes
# Total time:
# 	user time   =      91.43 seconds =       1.52 minutes
# 	system time =       3.09 seconds =       0.05 minutes
# 	total time  =      80392 seconds =    1339.87 minutes
#
# Scratch directory: /tmp/
#  MINTS: Wrapper to libmints.
#    by Justin Turney
#
#    Calculation information:
#       Number of threads:                 1
#       Number of atoms:                   2
#       Number of AO shells:               4
#       Number of SO shells:               4
#       Number of primitives:             12
#       Number of atomic orbitals:         6
#       Number of basis functions:         6
#
#       Number of irreps:                  1
#       Integral cutoff                 1.00e-12
#       Number of functions per irrep: [   6 ]
#
#  OEINTS: Overlap, kinetic, potential, dipole, and quadrupole integrals
#          stored in file 35.
#
#       Computing two-electron integrals...done
#       Computed 83 non-zero two-electron integrals.
#         Stored in file 33.
#
#
#          ---------------------------------------------------------
#                           Configuration Interaction
#                             (a 'D E T C I' module)
#
#                  C. David Sherrill, Daniel G. A. Smith, and
#                               Matt L. Leininger
#          ---------------------------------------------------------
#
#
#    ==> Parameters <==
#
#     EX LEVEL       =        4      H0 BLOCKSIZE  =     1000
#     VAL EX LEVEL   =        0      H0 GUESS SIZE =     1000
#     H0COUPLINGSIZE =        0      H0 COUPLING   =       NO
#     MAXITER        =       24      NUM PRINT     =       20
#     NUM ROOTS      =        1      ICORE         =        1
#     PRINT LVL      =        1      FCI           =      YES
#     R CONV         = 1.00e-04      MIXED         =      YES
#     E CONV         = 1.00e-10      MIXED4        =      YES
#     R4S            =       NO      REPL OTF      =       NO
#     DIAG METHOD    =      SEM      FOLLOW ROOT   =        0
#     PRECONDITIONER = DAVIDSON      UPDATE        = DAVIDSON
#     S              =   0.0000      Ms0           =      YES
#     GUESS VECTOR   =  H0BLOCK      OPENTYPE      =     NONE
#     COLLAPSE SIZE  =        1      HD AVG        = EVANGELISTI
#     MAX NUM VECS   =       25      REF SYM       =     AUTO
#     IOPEN        =       NO
#
#     EX ALLOW       =  1  1  1  1
#     STATE AVERAGE  =  0(1.00)
#
#    ==> CI Orbital and Space information <==
#
#    ------------------------------------
#                Space    Total     A
#    ------------------------------------
#                  Nso        6     6
#                  Nmo        6     6
#                Ndocc        2     2
#                Nsocc        0     0
#    ------------------------------------
#               CI Spaces
#    ------------------------------------
#         Dropped DOCC        0     0
#               Active        6     6
#         Dropped UOCC        0     0
#    ------------------------------------
#
#    ==> Setting up CI strings <==
#
#     There are 15 alpha and 15 beta strings
#     The CI space requires 225 (2.25E+02) determinants and 1 blocks
#
#    ==> Transforming CI integrals <==
#
# 	Presorting SO-basis two-electron integrals.
# 	Sorting File: SO Ints (nn|nn) nbuckets = 1
# 	Constructing frozen core operators
# 	Starting first half-transformation.
# 	Sorting half-transformed integrals.
# 	First half integral transformation complete.
# 	Starting second half-transformation.
# 	Two-electron integral transformation complete.
#
#    ==> Starting CI iterations <==
#
#     H0 Block Eigenvalue =  -7.81156369
#
#     Simultaneous Expansion Method (Block Davidson Method)
#     Using 1 initial trial vectors
#
#      Iter   Root       Total Energy       Delta E      C RMS
#
#    @CI  0:     0     -7.811563690401   -9.3075E+00   5.0073E-14
#     Warning: Norm of correction (root 0) is < 1.0E-13
#    @CI  1:     0     -7.811563690401   0.0000E+00   3.8106E-13 c
#
#    ==> Energetics <==
#
#     SCF energy =           -7.794688330028432
#     Total CI energy =      -7.811563690400759
#
#    ==> FCI root 0 information <==
#
#     FCI Root 0 energy =    -7.811563690400759
#
#    The 20 most important determinants:
#
#     *   1   -0.991046  (    0,    0)  1AX 2AX
#     *   2    0.095593  (   10,   10)  1AX 6AX
#     *   3   -0.043761  (    1,   10)  1AX 3AA 6AB
#     *   4   -0.043761  (   10,    1)  1AX 3AB 6AA
#     *   5    0.034847  (    6,    6)  1AX 5AX
#     *   6    0.034847  (    3,    3)  1AX 4AX
#     *   7   -0.030297  (    0,    1)  1AX 2AA 3AB
#     *   8   -0.030297  (    1,    0)  1AX 2AB 3AA
#     *   9    0.021948  (    1,    1)  1AX 3AX
#     *  10   -0.003531  (    2,   10)  1AB 2AA 3AA 6AB
#     *  11   -0.003531  (   10,    2)  1AA 2AB 3AB 6AA
#     *  12    0.003450  (    2,    2)  2AX 3AX
#     *  13    0.003009  (    3,    4)  1AA 2AB 4AX
#     *  14    0.003009  (    4,    3)  1AB 2AA 4AX
#     *  15    0.003009  (    6,    7)  1AA 2AB 5AX
#     *  16    0.003009  (    7,    6)  1AB 2AA 5AX
#     *  17    0.002511  (    0,   12)  1AA 2AA 3AB 6AB
#     *  18    0.002511  (   12,    0)  1AB 2AB 3AA 6AA
#     *  19    0.002440  (   10,   11)  1AA 2AB 6AX
#     *  20    0.002440  (   11,   10)  1AB 2AA 6AX
#
# 		 "A good bug is a dead bug"
#
# 			 - Starship Troopers
#
# 		 "I didn't write FORTRAN.  That's the problem."
#
# 			 - Edward Valeev
#
# Scratch directory: /tmp/
#    => Libint2 <=
#
#     Primary   basis highest AM E, G, H:  5, 4, 3
#     Auxiliary basis highest AM E, G, H:  6, 5, 4
#     Onebody   basis highest AM E, G, H:  6, 5, 4
#     Solid Harmonics ordering:            gaussian
#
# *** tstart() called on CHEMYM0V4HTALT
# *** at Thu Oct 12 13:51:31 2023
#
#    => Loading Basis Set <=
#
#     Name: STO-3G
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1 entry LI         line    31 file /Users/ptolley1/miniforge3/envs/work/share/psi4/basis/sto-3g.gbs
#     atoms 2 entry H          line    19 file /Users/ptolley1/miniforge3/envs/work/share/psi4/basis/sto-3g.gbs
#
#
#          ---------------------------------------------------------
#                                    SCF
#                by Justin Turney, Rob Parrish, Andy Simmonett
#                           and Daniel G. A. Smith
#                               RHF Reference
#                         1 Threads,    500 MiB Core
#          ---------------------------------------------------------
#
#   ==> Geometry <==
#
#     Molecular point group: c1
#     Full point group: C_inf_v
#
#     Geometry (in Angstrom), charge = 0, multiplicity = 1:
#
#        Center              X                  Y                   Z               Mass
#     ------------   -----------------  -----------------  -----------------  -----------------
#          LI           0.000000000000     0.000000000000    -0.133294051560     7.016003436600
#          H            0.000000000000     0.000000000000     0.927930438236     1.007825032230
#
#   Running in c1 symmetry.
#
#   Rotational constants: A = ************  B =     16.98590  C =     16.98590 [cm^-1]
#   Rotational constants: A = ************  B = 509224.59778  C = 509224.59778 [MHz]
#   Nuclear repulsion =    1.495943268624808
#
#   Charge       = 0
#   Multiplicity = 1
#   Electrons    = 4
#   Nalpha       = 2
#   Nbeta        = 2
#
#   ==> Algorithm <==
#
#   SCF Algorithm Type is PK.
#   DIIS enabled.
#   MOM disabled.
#   Fractional occupation disabled.
#   Guess Type is SAD.
#   Energy threshold   = 1.00e-10
#   Density threshold  = 1.00e-10
#   Integral threshold = 1.00e-12
#
#   ==> Primary Basis <==
#
#   Basis Set: STO-3G
#     Blend: STO-3G
#     Number of shells: 4
#     Number of basis functions: 6
#     Number of Cartesian functions: 6
#     Spherical Harmonics?: true
#     Max angular momentum: 1
#   ==> Integral Setup <==
#
#   Using in-core PK algorithm.
#    Calculation information:
#       Number of atoms:                   2
#       Number of AO shells:               4
#       Number of primitives:             12
#       Number of atomic orbitals:         6
#       Number of basis functions:         6
#
#       Integral cutoff                 1.00e-12
#       Number of threads:                 1
#
#   Performing in-core PK
#   Using 462 doubles for integral storage.
#   We computed 55 shell quartets total.
#   Whereas there are 55 unique shell quartets.
#
#   ==> DiskJK: Disk-Based J/K Matrices <==
#
#     J tasked:                  Yes
#     K tasked:                  Yes
#     wK tasked:                  No
#     Memory [MiB]:              375
#     Schwarz Cutoff:          1E-12
#
#     OpenMP threads:              1
#
#   Minimum eigenvalue in the overlap matrix is 2.3698916242E-01.
#   Reciprocal condition number of the overlap matrix is 1.2837061490E-01.
#     Using symmetric orthogonalization.
#
#   ==> Pre-Iterations <==
#
#   SCF Guess: Superposition of Atomic Densities via on-the-fly atomic UHF (no occupation information).
#
#    -------------------------
#     Irrep   Nso     Nmo
#    -------------------------
#      A          6       6
#    -------------------------
#     Total       6       6
#    -------------------------
#
#   ==> Iterations <==
#
#                         Total Energy        Delta E     RMS |[F,P]|
#
#    @RHF iter SAD:    -7.50772226593164   -7.50772e+00   0.00000e+00
#    @RHF iter   1:    -7.78566097647494   -2.77939e-01   1.42811e-02 ADIIS/DIIS
#    @RHF iter   2:    -7.79448531518342   -8.82434e-03   1.44310e-03 ADIIS/DIIS
#    @RHF iter   3:    -7.79465198710412   -1.66672e-04   4.31379e-04 ADIIS/DIIS
#    @RHF iter   4:    -7.79468632784678   -3.43407e-05   1.02659e-04 ADIIS/DIIS
#    @RHF iter   5:    -7.79468832986357   -2.00202e-06   9.08704e-07 DIIS
#    @RHF iter   6:    -7.79468833002843   -1.64858e-10   1.85027e-08 DIIS
#    @RHF iter   7:    -7.79468833002843   -7.10543e-15   5.79995e-10 DIIS
#    @RHF iter   8:    -7.79468833002843    2.66454e-15   9.09516e-12 DIIS
#   Energy and wave function converged.
#
#
#   ==> Post-Iterations <==
#
#     Orbital Energies [Eh]
#     ---------------------
#
#     Doubly Occupied:
#
#        1A     -2.361472     2A     -0.316699
#
#     Virtual:
#
#        3A      0.078047     4A      0.159303     5A      0.159303
#        6A      0.618872
#
#     Final Occupation by Irrep:
#               A
#     DOCC [     2 ]
#     NA   [     2 ]
#     NB   [     2 ]
#
#   @RHF Final Energy:    -7.79468833002843
#
#    => Energetics <=
#
#     Nuclear Repulsion Energy =              1.4959432686248075
#     One-Electron Energy =                 -13.2249202948479674
#     Two-Electron Energy =                   3.9342886961947277
#     Total Energy =                         -7.7946883300284320
#
# Computation Completed
#
#
# Properties will be evaluated at   0.000000,   0.000000,   0.000000 [a0]
#
# Properties computed using the SCF density matrix
#
#
#  Multipole Moments:
#
#  ------------------------------------------------------------------------------------
#      Multipole            Electronic (a.u.)      Nuclear  (a.u.)        Total (a.u.)
#  ------------------------------------------------------------------------------------
#
#  L = 1.  Multiply by 2.5417464519 to convert [e a0] to [Debye]
#  Dipole X            :         -0.0000000            0.0000000           -0.0000000
#  Dipole Y            :          0.0000000            0.0000000            0.0000000
#  Dipole Z            :         -2.8908566            0.9978666           -1.8929899
#  Magnitude           :                                                    1.8929899
#
#  ------------------------------------------------------------------------------------
#
# Start SCF iterations:
#
# Canonical RHF One-electron energy = -13.2249202949071130
# CQED-RHF One-electron energy      = -13.2249202949071130
# Nuclear repulsion energy          = 1.4959432686248075
# Dipole energy                     = 0.0000000000000000
#
# *** tstop() called on CHEMYM0V4HTALT at Thu Oct 12 13:51:31 2023
# Module time:
# 	user time   =       0.07 seconds =       0.00 minutes
# 	system time =       0.01 seconds =       0.00 minutes
# 	total time  =          0 seconds =       0.00 minutes
# Total time:
# 	user time   =      91.55 seconds =       1.53 minutes
# 	system time =       3.11 seconds =       0.05 minutes
# 	total time  =      80392 seconds =    1339.87 minutes
# SCF Iteration   1: Energy = -7.7946883300284382   dE = -7.79469E+00   dRMS = 1.12320E-14
# SCF Iteration   2: Energy = -7.7946883300284293   dE =  8.88178E-15   dRMS = 1.95637E-15
# Total time for SCF iterations: 0.000 seconds
#
# QED-RHF   energy: -7.79468833 hartree
# Psi4  SCF energy: -7.79468833 hartree
#  Completed QED-RHF in 0.09426188468933105 seconds
#    => Loading Basis Set <=
#
#     Name: STO-3G
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1 entry LI         line    31 file /Users/ptolley1/miniforge3/envs/work/share/psi4/basis/sto-3g.gbs
#     atoms 2 entry H          line    19 file /Users/ptolley1/miniforge3/envs/work/share/psi4/basis/sto-3g.gbs
#
#  Completed 1HSO Build in 0.00012111663818359375 seconds
#  Completed ERI Build in 0.001405954360961914 seconds
#  Completed 2D build in 0.00016808509826660156 seconds
#  Completed 1G build in 1.5974044799804688e-05 seconds
#  Completed the Dipole Matrix Build in 4.1961669921875e-05 seconds
#  Completed determinant list in 0.00043392181396484375 seconds
#  Completed constant offset matrix in 0.00015616416931152344 seconds
#  Completed Hamiltonian build in 0.7137589454650879 seconds
#
# Scratch directory: /tmp/
#    => Libint2 <=
#
#     Primary   basis highest AM E, G, H:  5, 4, 3
#     Auxiliary basis highest AM E, G, H:  6, 5, 4
#     Onebody   basis highest AM E, G, H:  6, 5, 4
#     Solid Harmonics ordering:            gaussian
#
# *** tstart() called on CHEMYM0V4HTALT
# *** at Thu Oct 12 13:51:32 2023
#
#    => Loading Basis Set <=
#
#     Name: STO-3G
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1 entry LI         line    31 file /Users/ptolley1/miniforge3/envs/work/share/psi4/basis/sto-3g.gbs
#     atoms 2 entry H          line    19 file /Users/ptolley1/miniforge3/envs/work/share/psi4/basis/sto-3g.gbs
#
#
#          ---------------------------------------------------------
#                                    SCF
#                by Justin Turney, Rob Parrish, Andy Simmonett
# ...
#     ------------   -----------------  -----------------  -----------------  -----------------
#          LI           0.000000000000     0.000000000000    -0.502416040495     7.016003436600
#          H            0.000000000000     0.000000000000     3.497583959505     1.007825032230
#
#   Running in c1 symmetry.
#
#   Rotational constants: A = ************  B =      1.19559  C =      1.19559 [cm^-1]
#   Rotational constants: A = ************  B =  35842.96419  C =  35842.96419 [MHz]
#   Nuclear repulsion =    0.396882908002500
#
#   Charge       = 0
#   Multiplicity = 1
#   Electrons    = 4
#   Nalpha       = 2
#   Nbeta        = 2
#
#   ==> Algorithm <==
#
#   SCF Algorithm Type is PK.
#   DIIS enabled.
#   MOM disabled.
#   Fractional occupation disabled.
#   Guess Type is SAD.
#   Energy threshold   = 1.00e-10
#   Density threshold  = 1.00e-10
#   Integral threshold = 1.00e-12
#
#   ==> Primary Basis <==
#
#   Basis Set: STO-3G
#     Blend: STO-3G
#     Number of shells: 4
#     Number of basis functions: 6
#     Number of Cartesian functions: 6
#     Spherical Harmonics?: true
#     Max angular momentum: 1
#
#   ==> Integral Setup <==
#   Using in-core PK algorithm.
#    Calculation information:
#       Number of atoms:                   2
#       Number of AO shells:               4
#       Number of primitives:             12
#       Number of atomic orbitals:         6
#       Number of basis functions:         6
#
#       Integral cutoff                 1.00e-12
#       Number of threads:                 1
#
#   Performing in-core PK
#   Using 462 doubles for integral storage.
#   We computed 55 shell quartets total.
#   Whereas there are 55 unique shell quartets.
#
#   ==> DiskJK: Disk-Based J/K Matrices <==
#
#     J tasked:                  Yes
#     K tasked:                  Yes
#     wK tasked:                  No
#     Memory [MiB]:              375
#     Schwarz Cutoff:          1E-12
#
#     OpenMP threads:              1
#
#   Minimum eigenvalue in the overlap matrix is 7.5500588372E-01.
#   Reciprocal condition number of the overlap matrix is 6.0642370193E-01.
#     Using symmetric orthogonalization.
#
#   ==> Pre-Iterations <==
#
#   SCF Guess: Superposition of Atomic Densities via on-the-fly atomic UHF (no occupation information).
#
#    -------------------------
#     Irrep   Nso     Nmo
#    -------------------------
#      A          6       6
#    -------------------------
#     Total       6       6
#    -------------------------
#
#   ==> Iterations <==
#
#                         Total Energy        Delta E     RMS |[F,P]|
#
#    @RHF iter SAD:    -7.40711045532986   -7.40711e+00   0.00000e+00
#    @RHF iter   1:    -7.46548499272682   -5.83745e-02   1.93836e-02 ADIIS/DIIS
#    @RHF iter   2:    -7.32265448465393    1.42831e-01   2.25590e-02 ADIIS/DIIS
#    @RHF iter   3:    -7.60599208349797   -2.83338e-01   1.41586e-02 ADIIS/DIIS
#    @RHF iter   4:    -7.58140134016265    2.45907e-02   1.98560e-02 ADIIS/DIIS
#    @RHF iter   5:    -7.62236197348085   -4.09606e-02   5.15401e-03 ADIIS/DIIS
#    @RHF iter   6:    -7.62496207803112   -2.60010e-03   3.02137e-04 ADIIS/DIIS
#    @RHF iter   7:    -7.62495623545587    5.84258e-06   4.66259e-04 ADIIS/DIIS
#    @RHF iter   8:    -7.62497540081742   -1.91654e-05   4.60793e-05 DIIS
#    @RHF iter   9:    -7.62497562006561   -2.19248e-07   1.01792e-05 DIIS
#    @RHF iter  10:    -7.62497562997463   -9.90902e-09   6.69625e-07 DIIS
#    @RHF iter  11:    -7.62497563001828   -4.36469e-11   2.52218e-08 DIIS
#    @RHF iter  12:    -7.62497563001835   -7.28306e-14   1.26626e-11 DIIS
#   Energy and wave function converged.
#
#
#   ==> Post-Iterations <==
#
#     Orbital Energies [Eh]
#     ---------------------
#
#     Doubly Occupied:
#
#        1A     -2.382998     2A     -0.130143
#
#     Virtual:
#
#        3A      0.034454     4A      0.146925     5A      0.146925
#        6A      0.162476
#
#     Final Occupation by Irrep:
#               A
#     DOCC [     2 ]
#     NA   [     2 ]
#     NB   [     2 ]
#
#   @RHF Final Energy:    -7.62497563001835
#
#    => Energetics <=
#
#     Nuclear Repulsion Energy =              0.3968829080025000
#     One-Electron Energy =                 -11.0174360797578235
#     Two-Electron Energy =                   2.9955775417369748
#     Total Energy =                         -7.6249756300183495
#
# Computation Completed
#
#
# Properties will be evaluated at   0.000000,   0.000000,   0.000000 [a0]
#
# Properties computed using the SCF density matrix
#
#
#  Multipole Moments:
#
#  ------------------------------------------------------------------------------------
#      Multipole            Electronic (a.u.)      Nuclear  (a.u.)        Total (a.u.)
#  ------------------------------------------------------------------------------------
#
#  L = 1.  Multiply by 2.5417464519 to convert [e a0] to [Debye]
#  Dipole X            :         -0.0000000            0.0000000           -0.0000000
#  Dipole Y            :          0.0000000            0.0000000            0.0000000
#  Dipole Z            :         -5.3840387            3.7611896           -1.6228491
#  Magnitude           :                                                    1.6228491
#
#  ------------------------------------------------------------------------------------
#
# Start SCF iterations:
#
# Canonical RHF One-electron energy = -11.0174360797591131
# CQED-RHF One-electron energy      = -11.0174360797591131
# Nuclear repulsion energy          = 0.3968829080025000
# Dipole energy                     = 0.0000000000000000
#
# *** tstop() called on CHEMYM0V4HTALT at Thu Oct 12 13:52:56 2023
# Module time:
# 	user time   =       0.07 seconds =       0.00 minutes
# 	system time =       0.01 seconds =       0.00 minutes
# 	total time  =          0 seconds =       0.00 minutes
# Total time:
# 	user time   =     174.59 seconds =       2.91 minutes
# 	system time =       5.64 seconds =       0.09 minutes
# 	total time  =      80477 seconds =    1341.28 minutes
# SCF Iteration   1: Energy = -7.6249756300183442   dE = -7.62498E+00   dRMS = 1.19874E-11
# SCF Iteration   2: Energy = -7.6249756300183460   dE = -1.77636E-15   dRMS = 1.63162E-11
# Total time for SCF iterations: 0.000 seconds
#
# QED-RHF   energy: -7.62497563 hartree
# Psi4  SCF energy: -7.62497563 hartree
#  Completed QED-RHF in 0.09566211700439453 seconds
#  Completed 1HSO Build in 5.888938903808594e-05 seconds
#  Completed ERI Build in 0.001493215560913086 seconds
#    => Loading Basis Set <=
#
#     Name: STO-3G
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1 entry LI         line    31 file /Users/ptolley1/miniforge3/envs/work/share/psi4/basis/sto-3g.gbs
#     atoms 2 entry H          line    19 file /Users/ptolley1/miniforge3/envs/work/share/psi4/basis/sto-3g.gbs
#
#  Completed 2D build in 0.00011873245239257812 seconds
#  Completed 1G build in 2.0265579223632812e-05 seconds
#  Completed the Dipole Matrix Build in 4.57763671875e-05 seconds
#  Completed determinant list in 0.0005810260772705078 seconds
#  Completed constant offset matrix in 0.00010275840759277344 seconds
#  Completed Hamiltonian build in 0.7085411548614502 seconds
#
# Scratch directory: /tmp/
#    => Libint2 <=
#
#     Primary   basis highest AM E, G, H:  5, 4, 3
#     Auxiliary basis highest AM E, G, H:  6, 5, 4
#     Onebody   basis highest AM E, G, H:  6, 5, 4
#     Solid Harmonics ordering:            gaussian
#
# *** tstart() called on CHEMYM0V4HTALT
# *** at Thu Oct 12 13:52:57 2023
#
#    => Loading Basis Set <=
#
#     Name: STO-3G
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1 entry LI         line    31 file /Users/ptolley1/miniforge3/envs/work/share/psi4/basis/sto-3g.gbs
#     atoms 2 entry H          line    19 file /Users/ptolley1/miniforge3/envs/work/share/psi4/basis/sto-3g.gbs
#
#
#          ---------------------------------------------------------
#                                    SCF
#                by Justin Turney, Rob Parrish, Andy Simmonett
#                           and Daniel G. A. Smith
#                               RHF Reference
#                         1 Threads,    500 MiB Core
#          ---------------------------------------------------------
#
#   ==> Geometry <==
#
#     Molecular point group: c1
#     Full point group: C_inf_v
#
#     Geometry (in Angstrom), charge = 0, multiplicity = 1:
#
#        Center              X                  Y                   Z               Mass
#     ------------   -----------------  -----------------  -----------------  -----------------
#          LI           0.000000000000     0.000000000000    -0.502416040495     7.016003436600
#          H            0.000000000000     0.000000000000     3.497583959505     1.007825032230
#
#   Running in c1 symmetry.
#
#   Rotational constants: A = ************  B =      1.19559  C =      1.19559 [cm^-1]
#   Rotational constants: A = ************  B =  35842.96419  C =  35842.96419 [MHz]
#   Nuclear repulsion =    0.396882908002500
#
#   Charge       = 0
#   Multiplicity = 1
#   Electrons    = 4
#   Nalpha       = 2
#   Nbeta        = 2
#
#   ==> Algorithm <==
#
#   SCF Algorithm Type is PK.
#   DIIS enabled.
#   MOM disabled.
#   Fractional occupation disabled.
#   Guess Type is SAD.
#   Energy threshold   = 1.00e-10
#   Density threshold  = 1.00e-10
#   Integral threshold = 1.00e-12
#
#   ==> Primary Basis <==
#
#   Basis Set: STO-3G
#     Blend: STO-3G
#     Number of shells: 4
#     Number of basis functions: 6
#     Number of Cartesian functions: 6
#     Spherical Harmonics?: true
#     Max angular momentum: 1
#
#   ==> Integral Setup <==
#
#   Using in-core PK algorithm.
#    Calculation information:
#       Number of atoms:                   2
#       Number of AO shells:               4
#       Number of primitives:             12
#       Number of atomic orbitals:         6
#       Number of basis functions:         6
#
#       Integral cutoff                 1.00e-12
#       Number of threads:                 1
#
#   Performing in-core PK
#   Using 462 doubles for integral storage.
#   We computed 55 shell quartets total.
#   Whereas there are 55 unique shell quartets.
#
#   ==> DiskJK: Disk-Based J/K Matrices <==
#
#     J tasked:                  Yes
#     K tasked:                  Yes
#     wK tasked:                  No
#     Memory [MiB]:              375
#     Schwarz Cutoff:          1E-12
#
#     OpenMP threads:              1
#
#   Minimum eigenvalue in the overlap matrix is 7.5500588372E-01.
#   Reciprocal condition number of the overlap matrix is 6.0642370193E-01.
#     Using symmetric orthogonalization.
#
#   ==> Pre-Iterations <==
#
#   SCF Guess: Superposition of Atomic Densities via on-the-fly atomic UHF (no occupation information).
#
#    -------------------------
#     Irrep   Nso     Nmo
#    -------------------------
#      A          6       6
#    -------------------------
#     Total       6       6
#    -------------------------
#
#   ==> Iterations <==
#
#                         Total Energy        Delta E     RMS |[F,P]|
#
#    @RHF iter SAD:    -7.40711045532986   -7.40711e+00   0.00000e+00
#    @RHF iter   1:    -7.46548499272682   -5.83745e-02   1.93836e-02 ADIIS/DIIS
#    @RHF iter   2:    -7.32265448465393    1.42831e-01   2.25590e-02 ADIIS/DIIS
#    @RHF iter   3:    -7.60599208349797   -2.83338e-01   1.41586e-02 ADIIS/DIIS
#    @RHF iter   4:    -7.58140134016265    2.45907e-02   1.98560e-02 ADIIS/DIIS
#    @RHF iter   5:    -7.62236197348085   -4.09606e-02   5.15401e-03 ADIIS/DIIS
#    @RHF iter   6:    -7.62496207803112   -2.60010e-03   3.02137e-04 ADIIS/DIIS
#    @RHF iter   7:    -7.62495623545587    5.84258e-06   4.66259e-04 ADIIS/DIIS
#    @RHF iter   8:    -7.62497540081742   -1.91654e-05   4.60793e-05 DIIS
#    @RHF iter   9:    -7.62497562006561   -2.19248e-07   1.01792e-05 DIIS
#    @RHF iter  10:    -7.62497562997463   -9.90902e-09   6.69625e-07 DIIS
#    @RHF iter  11:    -7.62497563001828   -4.36469e-11   2.52218e-08 DIIS
#    @RHF iter  12:    -7.62497563001835   -7.28306e-14   1.26626e-11 DIIS
#   Energy and wave function converged.
#
#
#   ==> Post-Iterations <==
#
#     Orbital Energies [Eh]
#     ---------------------
#
#     Doubly Occupied:
#
#        1A     -2.382998     2A     -0.130143
#
#     Virtual:
#
#        3A      0.034454     4A      0.146925     5A      0.146925
#        6A      0.162476
#
#     Final Occupation by Irrep:
#               A
#     DOCC [     2 ]
#     NA   [     2 ]
#     NB   [     2 ]
#
#   @RHF Final Energy:    -7.62497563001835
#
#    => Energetics <=
#
#     Nuclear Repulsion Energy =              0.3968829080025000
#     One-Electron Energy =                 -11.0174360797578235
#     Two-Electron Energy =                   2.9955775417369748
#     Total Energy =                         -7.6249756300183495
#
# Computation Completed
#
#
# Properties will be evaluated at   0.000000,   0.000000,   0.000000 [a0]
#
# Properties computed using the SCF density matrix
#
#
#  Multipole Moments:
#
#  ------------------------------------------------------------------------------------
#      Multipole            Electronic (a.u.)      Nuclear  (a.u.)        Total (a.u.)
#  ------------------------------------------------------------------------------------
#
#  L = 1.  Multiply by 2.5417464519 to convert [e a0] to [Debye]
#  Dipole X            :         -0.0000000            0.0000000           -0.0000000
#  Dipole Y            :          0.0000000            0.0000000            0.0000000
#  Dipole Z            :         -5.3840387            3.7611896           -1.6228491
#  Magnitude           :                                                    1.6228491
#
#  ------------------------------------------------------------------------------------
#
# Start SCF iterations:
#
# Canonical RHF One-electron energy = -11.0174360797591131
# CQED-RHF One-electron energy      = -10.9502409698340006
# Nuclear repulsion energy          = 0.3968829080025000
# Dipole energy                     = 0.0362348409709613
#
# *** tstop() called on CHEMYM0V4HTALT at Thu Oct 12 13:52:57 2023
# Module time:
# 	user time   =       0.06 seconds =       0.00 minutes
# 	system time =       0.01 seconds =       0.00 minutes
# 	total time  =          0 seconds =       0.00 minutes
# Total time:
# 	user time   =     175.42 seconds =       2.92 minutes
# 	system time =       5.67 seconds =       0.09 minutes
# 	total time  =      80478 seconds =    1341.30 minutes
# SCF Iteration   1: Energy = -7.5932130136017442   dE = -7.59321E+00   dRMS = 2.96304E-03
# SCF Iteration   2: Energy = -7.5947188453318084   dE = -1.50583E-03   dRMS = 2.24792E-03
# SCF Iteration   3: Energy = -7.5951523702261685   dE = -4.33525E-04   dRMS = 8.68419E-04
# SCF Iteration   4: Energy = -7.5953183933907180   dE = -1.66023E-04   dRMS = 9.86210E-05
# SCF Iteration   5: Energy = -7.5953201981982392   dE = -1.80481E-06   dRMS = 7.48562E-06
# SCF Iteration   6: Energy = -7.5953202048109851   dE = -6.61275E-09   dRMS = 2.18217E-07
# SCF Iteration   7: Energy = -7.5953202048210500   dE = -1.00648E-11   dRMS = 2.89238E-08
# SCF Iteration   8: Energy = -7.5953202048211530   dE = -1.03029E-13   dRMS = 2.88049E-09
# SCF Iteration   9: Energy = -7.5953202048211512   dE =  1.77636E-15   dRMS = 5.66112E-09
# SCF Iteration  10: Energy = -7.5953202048211601   dE = -8.88178E-15   dRMS = 7.92368E-14
# Total time for SCF iterations: 0.001 seconds
#
# QED-RHF   energy: -7.59532020 hartree
# Psi4  SCF energy: -7.62497563 hartree
#  Completed QED-RHF in 0.12948203086853027 seconds
#  Completed 1HSO Build in 5.507469177246094e-05 seconds
#  Completed ERI Build in 0.0010979175567626953 seconds
#    => Loading Basis Set <=
#
#     Name: STO-3G
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1 entry LI         line    31 file /Users/ptolley1/miniforge3/envs/work/share/psi4/basis/sto-3g.gbs
#     atoms 2 entry H          line    19 file /Users/ptolley1/miniforge3/envs/work/share/psi4/basis/sto-3g.gbs
#
#  Completed 2D build in 7.700920104980469e-05 seconds
#  Completed 1G build in 1.4066696166992188e-05 seconds
#  Completed the Dipole Matrix Build in 3.790855407714844e-05 seconds
#  Completed determinant list in 0.00043320655822753906 seconds
#  Completed constant offset matrix in 7.987022399902344e-05 seconds
#  Completed Hamiltonian build in 0.7138118743896484 seconds

# %%
# z-matrix for LIH
mol_str = """
Li
H 1 1.8
symmetry c1
"""

# options dictionary for the psi4 calculation
options_dict0 = {'basis': 'sto-3g',
               'save_jk': True, 
               'scf_type': 'pk',
               'e_convergence' : 1e-8,
               'd_convergence' : 1e-7
               }

# let's run a psi4 geometry optimization to get the optimal geometry

# set the options
psi4.set_options(options_dict0)

# first set the coordinates in init_string as the molecule's geometry 
mol0 = psi4.geometry(mol_str)

# now capture the psi4 geometry data with the guess coordinates
init_geometry_string = psi4.core.Molecule.create_psi4_string_from_molecule(mol0)

# run the geometry optimization
psi4.optimize("HF")

guess_geometry = mol0.geometry()

guess_string = psi4.core.Molecule.create_psi4_string_from_molecule(mol0)
# Out:
# 	Change in internal coordinate of 5.69e-01 exceeds limit of 5.00e-01.
# 	Skipping Hessian update for step 1.
# Scratch directory: /tmp/
# gradient() will perform analytic gradient computation.
#    => Libint2 <=
#
#     Primary   basis highest AM E, G, H:  5, 4, 3
#     Auxiliary basis highest AM E, G, H:  6, 5, 4
#     Onebody   basis highest AM E, G, H:  6, 5, 4
#     Solid Harmonics ordering:            gaussian
#
# *** tstart() called on CHEMYM0V4HTALT
# *** at Thu Oct 12 13:53:12 2023
#
#    => Loading Basis Set <=
#
#     Name: STO-3G
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1 entry LI         line    31 file /Users/ptolley1/miniforge3/envs/work/share/psi4/basis/sto-3g.gbs
#     atoms 2 entry H          line    19 file /Users/ptolley1/miniforge3/envs/work/share/psi4/basis/sto-3g.gbs
#
#
#          ---------------------------------------------------------
#                                    SCF
#                by Justin Turney, Rob Parrish, Andy Simmonett
#                           and Daniel G. A. Smith
#                               RHF Reference
#                         1 Threads,    500 MiB Core
#          ---------------------------------------------------------
#
#   ==> Geometry <==
#
#     Molecular point group: c1
#     Full point group: C_inf_v
#
#     Geometry (in Angstrom), charge = 0, multiplicity = 1:
#
#        Center              X                  Y                   Z               Mass
#     ------------   -----------------  -----------------  -----------------  -----------------
#          LI           0.000000000000     0.000000000000    -0.226087218223     7.016003436600
#          H            0.000000000000     0.000000000000     1.573912781777     1.007825032230
#
#   Running in c1 symmetry.
#
#   Rotational constants: A = ************  B =      5.90416  C =      5.90416 [cm^-1]
#   Rotational constants: A = ************  B = 177002.29231  C = 177002.29231 [MHz]
#   Nuclear repulsion =    0.881962017783333
#
#   Charge       = 0
#   Multiplicity = 1
#   Electrons    = 4
#   Nalpha       = 2
#   Nbeta        = 2
#
#   ==> Algorithm <==
#
#   SCF Algorithm Type is PK.
#   DIIS enabled.
#   MOM disabled.
#   Fractional occupation disabled.
#   Guess Type is SAD.
#   Energy threshold   = 1.00e-08
#   Density threshold  = 1.00e-07
#   Integral threshold = 1.00e-12
#
#   ==> Primary Basis <==
#
#   Basis Set: STO-3G
#     Blend: STO-3G
#     Number of shells: 4
#     Number of basis functions: 6
#     Number of Cartesian functions: 6
#     Spherical Harmonics?: true
#     Max angular momentum: 1
#
#   ==> Integral Setup <==
#
#   Using in-core PK algorithm.
#    Calculation information:
#       Number of atoms:                   2
#       Number of AO shells:               4
#       Number of primitives:             12
#       Number of atomic orbitals:         6
#       Number of basis functions:         6
#
#       Integral cutoff                 1.00e-12
#       Number of threads:                 1
#
#   Performing in-core PK
#   Using 462 doubles for integral storage.
#   We computed 55 shell quartets total.
#   Whereas there are 55 unique shell quartets.
#
#   ==> DiskJK: Disk-Based J/K Matrices <==
#
#     J tasked:                  Yes
#     K tasked:                  Yes
#     wK tasked:                  No
#     Memory [MiB]:              375
#     Schwarz Cutoff:          1E-12
#
#     OpenMP threads:              1
#
#   Minimum eigenvalue in the overlap matrix is 4.0638580054E-01.
#   Reciprocal condition number of the overlap matrix is 2.5156310472E-01.
#     Using symmetric orthogonalization.
#
#   ==> Pre-Iterations <==
#
#   SCF Guess: Superposition of Atomic Densities via on-the-fly atomic UHF (no occupation information).
#
#    -------------------------
#     Irrep   Nso     Nmo
#    -------------------------
#      A          6       6
#    -------------------------
#     Total       6       6
#    -------------------------
#
#   ==> Iterations <==
#
#                         Total Energy        Delta E     RMS |[F,P]|
#
#    @RHF iter SAD:    -7.43899364259102   -7.43899e+00   0.00000e+00
#    @RHF iter   1:    -7.82744533231194   -3.88452e-01   1.99564e-02 ADIIS/DIIS
#    @RHF iter   2:    -7.84961545306892   -2.21701e-02   1.65597e-03 ADIIS/DIIS
#    @RHF iter   3:    -7.84993605538991   -3.20602e-04   6.19837e-04 ADIIS/DIIS
#    @RHF iter   4:    -7.85001708079200   -8.10254e-05   9.73534e-05 DIIS
#    @RHF iter   5:    -7.85001869633519   -1.61554e-06   2.20510e-06 DIIS
#    @RHF iter   6:    -7.85001869709765   -7.62469e-10   5.06870e-08 DIIS
#   Energy and wave function converged.
#
#
#   ==> Post-Iterations <==
#
#     Orbital Energies [Eh]
#     ---------------------
#
#     Doubly Occupied:
#
#        1A     -2.354458     2A     -0.267760
#
#     Virtual:
#
#        3A      0.076041     4A      0.163499     5A      0.163499
#        6A      0.489685
#
#     Final Occupation by Irrep:
#               A
#     DOCC [     2 ]
#     NA   [     2 ]
#     NB   [     2 ]
#
#   @RHF Final Energy:    -7.85001869709765
#
#    => Energetics <=
#
#     Nuclear Repulsion Energy =              0.8819620177833333
#     One-Electron Energy =                 -12.2195251892501808
#     Two-Electron Energy =                   3.4875444743691930
#     Total Energy =                         -7.8500186970976547
#
# Computation Completed
#
#
# Properties will be evaluated at   0.000000,   0.000000,   0.000000 [a0]
#
# Properties computed using the SCF density matrix
#
#
#  Multipole Moments:
#
#  ------------------------------------------------------------------------------------
#      Multipole            Electronic (a.u.)      Nuclear  (a.u.)        Total (a.u.)
#  ------------------------------------------------------------------------------------
#
#  L = 1.  Multiply by 2.5417464519 to convert [e a0] to [Debye]
#  Dipole X            :         -0.0000000            0.0000000           -0.0000000
#  Dipole Y            :         -0.0000000            0.0000000           -0.0000000
#  Dipole Z            :         -3.6288095            1.6925353           -1.9362742
#  Magnitude           :                                                    1.9362742
#
#  ------------------------------------------------------------------------------------
#
# *** tstop() called on CHEMYM0V4HTALT at Thu Oct 12 13:53:12 2023
# Module time:
# 	user time   =       0.06 seconds =       0.00 minutes
# 	system time =       0.00 seconds =       0.00 minutes
# 	total time  =          0 seconds =       0.00 minutes
# Total time:
# 	user time   =     176.43 seconds =       2.94 minutes
# 	system time =       5.70 seconds =       0.10 minutes
# 	total time  =      80493 seconds =    1341.55 minutes
#
# *** tstart() called on CHEMYM0V4HTALT
# *** at Thu Oct 12 13:53:12 2023
#
#
#          ------------------------------------------------------------
#                                    SCF GRAD
#                           Rob Parrish, Justin Turney,
#                        Andy Simmonett, and Alex Sokolov
#          ------------------------------------------------------------
#
#   ==> Geometry <==
#
#     Molecular point group: c1
#     Full point group: C_inf_v
#
#     Geometry (in Angstrom), charge = 0, multiplicity = 1:
#
#        Center              X                  Y                   Z               Mass
#     ------------   -----------------  -----------------  -----------------  -----------------
#          LI           0.000000000000     0.000000000000    -0.226087218223     7.016003436600
#          H            0.000000000000     0.000000000000     1.573912781777     1.007825032230
#
#   Nuclear repulsion =    0.881962017783333
#
#   ==> Basis Set <==
#
#   Basis Set: STO-3G
#     Blend: STO-3G
#     Number of shells: 4
#     Number of basis functions: 6
#     Number of Cartesian functions: 6
#     Spherical Harmonics?: true
#     Max angular momentum: 1
#
#   ==> DirectJKGrad: Integral-Direct SCF Gradients <==
#
#     Gradient:                    1
#     J tasked:                  Yes
#     K tasked:                  Yes
#     wK tasked:                  No
#     Integrals threads:           1
#     Schwarz Cutoff:          1E-12
#
#
#   -Total Gradient:
#      Atom            X                  Y                   Z
#     ------   -----------------  -----------------  -----------------
#        1        0.000000000000     0.000000000000    -0.042902025581
#        2       -0.000000000000    -0.000000000000     0.042902025581
#
#
# *** tstop() called on CHEMYM0V4HTALT at Thu Oct 12 13:53:12 2023
# Module time:
# 	user time   =       0.00 seconds =       0.00 minutes
# 	system time =       0.00 seconds =       0.00 minutes
# 	total time  =          0 seconds =       0.00 minutes
# Total time:
# 	user time   =     176.43 seconds =       2.94 minutes
# 	system time =       5.70 seconds =       0.10 minutes
# 	total time  =      80493 seconds =    1341.55 minutes
#
#     			-----------------------------------------
#
#     			 OPTKING 3.0: for geometry optimizations
#
#     			     By R.A. King, Bethel University
#
#     			        with contributions from
#
#     			    A.V. Copan, J. Cayton, A. Heide
#
#     			-----------------------------------------
#
#
# 	                            ===> Fragment 1 <==
#
# 	 Z (Atomic Numbers)          Masses                          Geom
# 	       3.000000             7.016003          0.00000000  0.00000000 -0.42724292
# 	       1.000000             1.007825          0.00000000  0.00000000  2.97426410
#
# 	 - Coordinate -           - BOHR/RAD -       - ANG/DEG -
# 	 R(1,2)           =         3.401507           1.800000
#
#
# 	        --- Internal Coordinate Step in ANG or DEG, aJ/ANG or AJ/DEG ---
# 	-------------------------------------------------------------------------------
# 	           Coordinate      Previous         Force          Change          New
# 	           ----------      --------        ------          ------        ------
# 	               R(1,2)       1.80000       -0.35346       -0.26459       1.53541
# 	-------------------------------------------------------------------------------
#
# 	                                 ==> Convergence Check <==
#
# 	Measures of convergence in internal coordinates in au.
#
# 	Criteria marked as inactive (o), active & met (*), and active & unmet ( ).
#
# 	----------------------------------------------------------------------------------------------
# 	   Step    Total Energy     Delta E     Max Force     RMS Force      Max Disp      RMS Disp
# 	----------------------------------------------------------------------------------------------
# 	  Convergence Criteria     1.00e-06 *    3.00e-04 *             o    1.20e-03 *             o
# 	----------------------------------------------------------------------------------------------
# 	     1      -7.85001870   -7.85e+00      4.29e-02      4.29e-02 o    5.00e-01      5.00e-01 o  ~
# 	----------------------------------------------------------------------------------------------
#
# Next Geometry in Ang
# 	Fragment 1 (Ang)
#
# 	   Li   0.0000000000   0.0000000000  -0.0937923651
# 	    H   0.0000000000   0.0000000000   1.4416179286
#
#
#     Structure for next step:
#     Molecular point group: c1
#     Full point group: C_inf_v
#
#     Geometry (in Angstrom), charge = 0, multiplicity = 1:
#
#     LI
#     H             1    1.535410
#
#
# Scratch directory: /tmp/
# gradient() will perform analytic gradient computation.
#    => Libint2 <=
#
#     Primary   basis highest AM E, G, H:  5, 4, 3
#     Auxiliary basis highest AM E, G, H:  6, 5, 4
#     Onebody   basis highest AM E, G, H:  6, 5, 4
#     Solid Harmonics ordering:            gaussian
#
# *** tstart() called on CHEMYM0V4HTALT
# *** at Thu Oct 12 13:53:12 2023
#
#    => Loading Basis Set <=
#
#     Name: STO-3G
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1 entry LI         line    31 file /Users/ptolley1/miniforge3/envs/work/share/psi4/basis/sto-3g.gbs
#     atoms 2 entry H          line    19 file /Users/ptolley1/miniforge3/envs/work/share/psi4/basis/sto-3g.gbs
#
#
#          ---------------------------------------------------------
#                                    SCF
#                by Justin Turney, Rob Parrish, Andy Simmonett
#                           and Daniel G. A. Smith
#                               RHF Reference
#                         1 Threads,    500 MiB Core
#          ---------------------------------------------------------
#
#   ==> Geometry <==
#
#     Molecular point group: c1
#     Full point group: C_inf_v
#
#     Geometry (in Angstrom), charge = 0, multiplicity = 1:
#
#        Center              X                  Y                   Z               Mass
#     ------------   -----------------  -----------------  -----------------  -----------------
#          LI           0.000000000000     0.000000000000    -0.192853690074     7.016003436600
#          H            0.000000000000     0.000000000000     1.342556603627     1.007825032230
#
#   Running in c1 symmetry.
#
#   Rotational constants: A = ************  B =      8.11436  C =      8.11436 [cm^-1]
#   Rotational constants: A = ************  B = 243262.41016  C = 243262.41016 [MHz]
#   Nuclear repulsion =    1.033946195699170
#
#   Charge       = 0
#   Multiplicity = 1
#   Electrons    = 4
#   Nalpha       = 2
#   Nbeta        = 2
#
#   ==> Algorithm <==
#
#   SCF Algorithm Type is PK.
#   DIIS enabled.
#   MOM disabled.
#   Fractional occupation disabled.
#   Guess Type is READ.
#   Energy threshold   = 1.00e-08
#   Density threshold  = 1.00e-07
#   Integral threshold = 1.00e-12
#
#   ==> Primary Basis <==
#
#   Basis Set: STO-3G
#     Blend: STO-3G
#     Number of shells: 4
#     Number of basis functions: 6
#     Number of Cartesian functions: 6
#     Spherical Harmonics?: true
#     Max angular momentum: 1
#
#    => Loading Basis Set <=
#
#     Name: STO-3G
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1 entry LI         line    31 file /Users/ptolley1/miniforge3/envs/work/share/psi4/basis/sto-3g.gbs
#     atoms 2 entry H          line    19 file /Users/ptolley1/miniforge3/envs/work/share/psi4/basis/sto-3g.gbs
#
#   Reading orbitals from file /tmp/stdout.default.57672.180.npy, no projection.
#
#   ==> Integral Setup <==
#
#   Using in-core PK algorithm.
#    Calculation information:
#       Number of atoms:                   2
#       Number of AO shells:               4
#       Number of primitives:             12
#       Number of atomic orbitals:         6
#       Number of basis functions:         6
#
#       Integral cutoff                 1.00e-12
#       Number of threads:                 1
#
#   Performing in-core PK
#   Using 462 doubles for integral storage.
#   We computed 55 shell quartets total.
#   Whereas there are 55 unique shell quartets.
#
#   ==> DiskJK: Disk-Based J/K Matrices <==
#
#     J tasked:                  Yes
#     K tasked:                  Yes
#     wK tasked:                  No
#     Memory [MiB]:              375
#     Schwarz Cutoff:          1E-12
#
#     OpenMP threads:              1
#
#   Minimum eigenvalue in the overlap matrix is 3.2906223571E-01.
#   Reciprocal condition number of the overlap matrix is 1.9295390535E-01.
#     Using symmetric orthogonalization.
#
#   ==> Pre-Iterations <==
#
#   SCF Guess: Orbitals guess was supplied from a previous computation.
#
#    -------------------------------------------------------
#     Irrep   Nso     Nmo     Nalpha   Nbeta   Ndocc  Nsocc
#    -------------------------------------------------------
#      A          6       6       2       2       2       0
#    -------------------------------------------------------
#     Total       6       6       2       2       2       0
#    -------------------------------------------------------
#
#   ==> Iterations <==
#
#                         Total Energy        Delta E     RMS |[F,P]|
#
#    @RHF iter   0:    -7.89328174685340   -7.89328e+00   1.03109e-02
#    @RHF iter   1:    -7.86307891112314    3.02028e-02   1.53830e-03 ADIIS/DIIS
#    @RHF iter   2:    -7.86323860171236   -1.59691e-04   3.24962e-04 ADIIS/DIIS
#    @RHF iter   3:    -7.86325476460345   -1.61629e-05   1.56618e-04 ADIIS/DIIS
#    @RHF iter   4:    -7.86325949225435   -4.72765e-06   1.97149e-06 DIIS
#    @RHF iter   5:    -7.86325949249453   -2.40182e-10   1.08217e-07 DIIS
#    @RHF iter   6:    -7.86325949249507   -5.40901e-13   3.00824e-09 DIIS
#   Energy and wave function converged.
#
#
#   ==> Post-Iterations <==
#
#     Orbital Energies [Eh]
#     ---------------------
#
#     Doubly Occupied:
#
#        1A     -2.347418     2A     -0.290684
#
#     Virtual:
#
#        3A      0.078746     4A      0.163850     5A      0.163850
#        6A      0.565231
#
#     Final Occupation by Irrep:
#               A
#     DOCC [     2 ]
#     NA   [     2 ]
#     NB   [     2 ]
#
#   @RHF Final Energy:    -7.86325949249507
#
#    => Energetics <=
#
#     Nuclear Repulsion Energy =              1.0339461956991705
#     One-Electron Energy =                 -12.5182071961104082
#     Two-Electron Energy =                   3.6210015079161653
#     Total Energy =                         -7.8632594924950716
#
# Computation Completed
#
#
# Properties will be evaluated at   0.000000,   0.000000,   0.000000 [a0]
#
# Properties computed using the SCF density matrix
#
#
#  Multipole Moments:
#
#  ------------------------------------------------------------------------------------
#      Multipole            Electronic (a.u.)      Nuclear  (a.u.)        Total (a.u.)
#  ------------------------------------------------------------------------------------
#
#  L = 1.  Multiply by 2.5417464519 to convert [e a0] to [Debye]
#  Dipole X            :          0.0000000            0.0000000            0.0000000
#  Dipole Y            :         -0.0000000            0.0000000           -0.0000000
#  Dipole Z            :         -3.3494958            1.4437423           -1.9057535
#  Magnitude           :                                                    1.9057535
#
#  ------------------------------------------------------------------------------------
#
# *** tstop() called on CHEMYM0V4HTALT at Thu Oct 12 13:53:12 2023
# Module time:
# 	user time   =       0.04 seconds =       0.00 minutes
# 	system time =       0.01 seconds =       0.00 minutes
# 	total time  =          0 seconds =       0.00 minutes
# Total time:
# 	user time   =     176.49 seconds =       2.94 minutes
# 	system time =       5.71 seconds =       0.10 minutes
# 	total time  =      80493 seconds =    1341.55 minutes
#
# *** tstart() called on CHEMYM0V4HTALT
# *** at Thu Oct 12 13:53:12 2023
#
#
#          ------------------------------------------------------------
#                                    SCF GRAD
#                           Rob Parrish, Justin Turney,
#                        Andy Simmonett, and Alex Sokolov
#          ------------------------------------------------------------
#
#   ==> Geometry <==
#
#     Molecular point group: c1
#     Full point group: C_inf_v
#
#     Geometry (in Angstrom), charge = 0, multiplicity = 1:
#
#        Center              X                  Y                   Z               Mass
#     ------------   -----------------  -----------------  -----------------  -----------------
#          LI           0.000000000000     0.000000000000    -0.192853690074     7.016003436600
#          H            0.000000000000     0.000000000000     1.342556603627     1.007825032230
#
#   Nuclear repulsion =    1.033946195699170
#
#   ==> Basis Set <==
#
#   Basis Set: STO-3G
#     Blend: STO-3G
#     Number of shells: 4
#     Number of basis functions: 6
#     Number of Cartesian functions: 6
#     Spherical Harmonics?: true
#     Max angular momentum: 1
#
#   ==> DirectJKGrad: Integral-Direct SCF Gradients <==
#
#     Gradient:                    1
#     J tasked:                  Yes
#     K tasked:                  Yes
#     wK tasked:                  No
#     Integrals threads:           1
#     Schwarz Cutoff:          1E-12
#
#
#   -Total Gradient:
#      Atom            X                  Y                   Z
#     ------   -----------------  -----------------  -----------------
#        1       -0.000000000000     0.000000000000    -0.005214531599
#        2        0.000000000000    -0.000000000000     0.005214531599
#
#
# *** tstop() called on CHEMYM0V4HTALT at Thu Oct 12 13:53:12 2023
# Module time:
# 	user time   =       0.00 seconds =       0.00 minutes
# 	system time =       0.00 seconds =       0.00 minutes
# 	total time  =          0 seconds =       0.00 minutes
# Total time:
# 	user time   =     176.49 seconds =       2.94 minutes
# 	system time =       5.71 seconds =       0.10 minutes
# 	total time  =      80493 seconds =    1341.55 minutes
#
#     			-----------------------------------------
#
#     			 OPTKING 3.0: for geometry optimizations
#
#     			     By R.A. King, Bethel University
#
#     			        with contributions from
#
#     			    A.V. Copan, J. Cayton, A. Heide
#
#     			-----------------------------------------
#
#
# 	                            ===> Fragment 1 <==
#
# 	 Z (Atomic Numbers)          Masses                          Geom
# 	       3.000000             7.016003          0.00000000  0.00000000 -0.36444066
# 	       1.000000             1.007825          0.00000000  0.00000000  2.53706429
#
# 	 - Coordinate -           - BOHR/RAD -       - ANG/DEG -
# 	 R(1,2)           =         2.901505           1.535410
#
#
# 	        --- Internal Coordinate Step in ANG or DEG, aJ/ANG or AJ/DEG ---
# 	-------------------------------------------------------------------------------
# 	           Coordinate      Previous         Force          Change          New
# 	           ----------      --------        ------          ------        ------
# 	               R(1,2)       1.53541       -0.04296       -0.03644       1.49897
# 	-------------------------------------------------------------------------------
#
# 	                                 ==> Convergence Check <==
#
# 	Measures of convergence in internal coordinates in au.
#
# 	Criteria marked as inactive (o), active & met (*), and active & unmet ( ).
#
# 	----------------------------------------------------------------------------------------------
# 	   Step    Total Energy     Delta E     Max Force     RMS Force      Max Disp      RMS Disp
# 	----------------------------------------------------------------------------------------------
# 	  Convergence Criteria     1.00e-06 *    3.00e-04 *             o    1.20e-03 *             o
# 	----------------------------------------------------------------------------------------------
# 	     2      -7.86325949   -1.32e-02      5.21e-03      5.21e-03 o    6.89e-02      6.89e-02 o  ~
# 	----------------------------------------------------------------------------------------------
#
# Next Geometry in Ang
# 	Fragment 1 (Ang)
#
# 	   Li   0.0000000000   0.0000000000  -0.1746358372
# 	    H   0.0000000000   0.0000000000   1.3243387507
#
#
#     Structure for next step:
#     Molecular point group: c1
#     Full point group: C_inf_v
#
#     Geometry (in Angstrom), charge = 0, multiplicity = 1:
#
#     LI
#     H             1    1.498975
#
#
# Scratch directory: /tmp/
# gradient() will perform analytic gradient computation.
#    => Libint2 <=
#
#     Primary   basis highest AM E, G, H:  5, 4, 3
#     Auxiliary basis highest AM E, G, H:  6, 5, 4
#     Onebody   basis highest AM E, G, H:  6, 5, 4
#     Solid Harmonics ordering:            gaussian
#
# *** tstart() called on CHEMYM0V4HTALT
# *** at Thu Oct 12 13:53:12 2023
#
#    => Loading Basis Set <=
#
#     Name: STO-3G
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1 entry LI         line    31 file /Users/ptolley1/miniforge3/envs/work/share/psi4/basis/sto-3g.gbs
#     atoms 2 entry H          line    19 file /Users/ptolley1/miniforge3/envs/work/share/psi4/basis/sto-3g.gbs
#
#
#          ---------------------------------------------------------
#                                    SCF
#                by Justin Turney, Rob Parrish, Andy Simmonett
#                           and Daniel G. A. Smith
#                               RHF Reference
#                         1 Threads,    500 MiB Core
#          ---------------------------------------------------------
#
#   ==> Geometry <==
#
#     Molecular point group: c1
#     Full point group: C_inf_v
#
#     Geometry (in Angstrom), charge = 0, multiplicity = 1:
#
#        Center              X                  Y                   Z               Mass
#     ------------   -----------------  -----------------  -----------------  -----------------
#          LI           0.000000000000     0.000000000000    -0.188277219320     7.016003436600
#          H            0.000000000000     0.000000000000     1.310697368626     1.007825032230
#
#   Running in c1 symmetry.
#
#   Rotational constants: A = ************  B =      8.51363  C =      8.51363 [cm^-1]
#   Rotational constants: A = ************  B = 255232.13913  C = 255232.13913 [MHz]
#   Nuclear repulsion =    1.059078415856197
#
#   Charge       = 0
#   Multiplicity = 1
#   Electrons    = 4
#   Nalpha       = 2
#   Nbeta        = 2
#
#   ==> Algorithm <==
#
#   SCF Algorithm Type is PK.
#   DIIS enabled.
#   MOM disabled.
#   Fractional occupation disabled.
#   Guess Type is READ.
#   Energy threshold   = 1.00e-08
#   Density threshold  = 1.00e-07
#   Integral threshold = 1.00e-12
#
#   ==> Primary Basis <==
#
#   Basis Set: STO-3G
#     Blend: STO-3G
#     Number of shells: 4
#     Number of basis functions: 6
#     Number of Cartesian functions: 6
#     Spherical Harmonics?: true
#     Max angular momentum: 1
#
#    => Loading Basis Set <=
#
#     Name: STO-3G
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1 entry LI         line    31 file /Users/ptolley1/miniforge3/envs/work/share/psi4/basis/sto-3g.gbs
#     atoms 2 entry H          line    19 file /Users/ptolley1/miniforge3/envs/work/share/psi4/basis/sto-3g.gbs
#
#   Reading orbitals from file /tmp/stdout.default.57672.180.npy, no projection.
#
#   ==> Integral Setup <==
#
#   Using in-core PK algorithm.
#    Calculation information:
#       Number of atoms:                   2
#       Number of AO shells:               4
#       Number of primitives:             12
#       Number of atomic orbitals:         6
#       Number of basis functions:         6
#
#       Integral cutoff                 1.00e-12
#       Number of threads:                 1
#
#   Performing in-core PK
#   Using 462 doubles for integral storage.
#   We computed 55 shell quartets total.
#   Whereas there are 55 unique shell quartets.
#
#   ==> DiskJK: Disk-Based J/K Matrices <==
#
#     J tasked:                  Yes
#     K tasked:                  Yes
#     wK tasked:                  No
#     Memory [MiB]:              375
#     Schwarz Cutoff:          1E-12
#
#     OpenMP threads:              1
#
#   Minimum eigenvalue in the overlap matrix is 3.1945595667E-01.
#   Reciprocal condition number of the overlap matrix is 1.8602030538E-01.
#     Using symmetric orthogonalization.
#
#   ==> Pre-Iterations <==
#
#   SCF Guess: Orbitals guess was supplied from a previous computation.
#
#    -------------------------------------------------------
#     Irrep   Nso     Nmo     Nalpha   Nbeta   Ndocc  Nsocc
#    -------------------------------------------------------
#      A          6       6       2       2       2       0
#    -------------------------------------------------------
#     Total       6       6       2       2       2       0
#    -------------------------------------------------------
#
#   ==> Iterations <==
#
#                         Total Energy        Delta E     RMS |[F,P]|
#
#    @RHF iter   0:    -7.86702572225503   -7.86703e+00   1.75129e-03
#    @RHF iter   1:    -7.86334977814363    3.67594e-03   1.92957e-04 ADIIS/DIIS
#    @RHF iter   2:    -7.86335233816008   -2.56002e-06   4.43453e-05 DIIS
#    @RHF iter   3:    -7.86335263757500   -2.99415e-07   2.10834e-05 DIIS
#    @RHF iter   4:    -7.86335272295907   -8.53841e-08   2.36137e-07 DIIS
#    @RHF iter   5:    -7.86335272296325   -4.17888e-12   1.79056e-09 DIIS
#   Energy and wave function converged.
#
#
#   ==> Post-Iterations <==
#
#     Orbital Energies [Eh]
#     ---------------------
#
#     Doubly Occupied:
#
#        1A     -2.346821     2A     -0.293643
#
#     Virtual:
#
#        3A      0.078999     4A      0.163746     5A      0.163746
#        6A      0.574553
#
#     Final Occupation by Irrep:
#               A
#     DOCC [     2 ]
#     NA   [     2 ]
#     NB   [     2 ]
#
#   @RHF Final Energy:    -7.86335272296325
#
#    => Energetics <=
#
#     Nuclear Repulsion Energy =              1.0590784158561970
#     One-Electron Energy =                 -12.5639340991307620
#     Two-Electron Energy =                   3.6415029603113185
#     Total Energy =                         -7.8633527229632465
#
# Computation Completed
#
#
# Properties will be evaluated at   0.000000,   0.000000,   0.000000 [a0]
#
# Properties computed using the SCF density matrix
#
#
#  Multipole Moments:
#
#  ------------------------------------------------------------------------------------
#      Multipole            Electronic (a.u.)      Nuclear  (a.u.)        Total (a.u.)
#  ------------------------------------------------------------------------------------
#
#  L = 1.  Multiply by 2.5417464519 to convert [e a0] to [Debye]
#  Dipole X            :          0.0000000            0.0000000            0.0000000
#  Dipole Y            :         -0.0000000            0.0000000           -0.0000000
#  Dipole Z            :         -3.3124417            1.4094819           -1.9029598
#  Magnitude           :                                                    1.9029598
#
#  ------------------------------------------------------------------------------------
#
# *** tstop() called on CHEMYM0V4HTALT at Thu Oct 12 13:53:12 2023
# Module time:
# 	user time   =       0.03 seconds =       0.00 minutes
# 	system time =       0.00 seconds =       0.00 minutes
# 	total time  =          0 seconds =       0.00 minutes
# Total time:
# 	user time   =     176.54 seconds =       2.94 minutes
# 	system time =       5.71 seconds =       0.10 minutes
# 	total time  =      80493 seconds =    1341.55 minutes
#
# *** tstart() called on CHEMYM0V4HTALT
# *** at Thu Oct 12 13:53:12 2023
#
#
#          ------------------------------------------------------------
#                                    SCF GRAD
#                           Rob Parrish, Justin Turney,
#                        Andy Simmonett, and Alex Sokolov
#          ------------------------------------------------------------
#
#   ==> Geometry <==
#
#     Molecular point group: c1
#     Full point group: C_inf_v
#
#     Geometry (in Angstrom), charge = 0, multiplicity = 1:
#
#        Center              X                  Y                   Z               Mass
#     ------------   -----------------  -----------------  -----------------  -----------------
#          LI           0.000000000000     0.000000000000    -0.188277219320     7.016003436600
#          H            0.000000000000     0.000000000000     1.310697368626     1.007825032230
#
#   Nuclear repulsion =    1.059078415856197
#
#   ==> Basis Set <==
#
#   Basis Set: STO-3G
#     Blend: STO-3G
#     Number of shells: 4
#     Number of basis functions: 6
#     Number of Cartesian functions: 6
#     Spherical Harmonics?: true
#     Max angular momentum: 1
#
#   ==> DirectJKGrad: Integral-Direct SCF Gradients <==
#
#     Gradient:                    1
#     J tasked:                  Yes
#     K tasked:                  Yes
#     wK tasked:                  No
#     Integrals threads:           1
#     Schwarz Cutoff:          1E-12
#
#
#   -Total Gradient:
#      Atom            X                  Y                   Z
#     ------   -----------------  -----------------  -----------------
#        1       -0.000000000000     0.000000000000     0.002644370398
#        2        0.000000000000    -0.000000000000    -0.002644370398
#
#
# *** tstop() called on CHEMYM0V4HTALT at Thu Oct 12 13:53:12 2023
# Module time:
# 	user time   =       0.00 seconds =       0.00 minutes
# 	system time =       0.00 seconds =       0.00 minutes
# 	total time  =          0 seconds =       0.00 minutes
# Total time:
# 	user time   =     176.54 seconds =       2.94 minutes
# 	system time =       5.71 seconds =       0.10 minutes
# 	total time  =      80493 seconds =    1341.55 minutes
#
#     			-----------------------------------------
#
#     			 OPTKING 3.0: for geometry optimizations
#
#     			     By R.A. King, Bethel University
#
#     			        with contributions from
#
#     			    A.V. Copan, J. Cayton, A. Heide
#
#     			-----------------------------------------
#
#
# 	                            ===> Fragment 1 <==
#
# 	 Z (Atomic Numbers)          Masses                          Geom
# 	       3.000000             7.016003          0.00000000  0.00000000 -0.35579238
# 	       1.000000             1.007825          0.00000000  0.00000000  2.47685906
#
# 	 - Coordinate -           - BOHR/RAD -       - ANG/DEG -
# 	 R(1,2)           =         2.832651           1.498975
#
#
# 	        --- Internal Coordinate Step in ANG or DEG, aJ/ANG or AJ/DEG ---
# 	-------------------------------------------------------------------------------
# 	           Coordinate      Previous         Force          Change          New
# 	           ----------      --------        ------          ------        ------
# 	               R(1,2)       1.49897        0.02179        0.01225       1.51123
# 	-------------------------------------------------------------------------------
#
# 	                                 ==> Convergence Check <==
#
# 	Measures of convergence in internal coordinates in au.
#
# 	Criteria marked as inactive (o), active & met (*), and active & unmet ( ).
#
# 	----------------------------------------------------------------------------------------------
# 	   Step    Total Energy     Delta E     Max Force     RMS Force      Max Disp      RMS Disp
# 	----------------------------------------------------------------------------------------------
# 	  Convergence Criteria     1.00e-06 *    3.00e-04 *             o    1.20e-03 *             o
# 	----------------------------------------------------------------------------------------------
# 	     3      -7.86335272   -9.32e-05      2.64e-03      2.64e-03 o    2.32e-02      2.32e-02 o  ~
# 	----------------------------------------------------------------------------------------------
#
# Next Geometry in Ang
# 	Fragment 1 (Ang)
#
# 	   Li   0.0000000000   0.0000000000  -0.1944038921
# 	    H   0.0000000000   0.0000000000   1.3168240414
#
#
#     Structure for next step:
#     Molecular point group: c1
#     Full point group: C_inf_v
#
#     Geometry (in Angstrom), charge = 0, multiplicity = 1:
#
#     LI
#     H             1    1.511228
#
#
# Scratch directory: /tmp/
# gradient() will perform analytic gradient computation.
#    => Libint2 <=
#
#     Primary   basis highest AM E, G, H:  5, 4, 3
#     Auxiliary basis highest AM E, G, H:  6, 5, 4
#     Onebody   basis highest AM E, G, H:  6, 5, 4
#     Solid Harmonics ordering:            gaussian
#
# *** tstart() called on CHEMYM0V4HTALT
# *** at Thu Oct 12 13:53:12 2023
# 	Change in internal coordinate of 5.46e-01 exceeds limit of 5.00e-01.
# 	Skipping Hessian update for step 1.
#    => Loading Basis Set <=
#
#     Name: STO-3G
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1 entry LI         line    31 file /Users/ptolley1/miniforge3/envs/work/share/psi4/basis/sto-3g.gbs
#     atoms 2 entry H          line    19 file /Users/ptolley1/miniforge3/envs/work/share/psi4/basis/sto-3g.gbs
#
#
#          ---------------------------------------------------------
#                                    SCF
#                by Justin Turney, Rob Parrish, Andy Simmonett
#                           and Daniel G. A. Smith
#                               RHF Reference
#                         1 Threads,    500 MiB Core
#          ---------------------------------------------------------
#
#   ==> Geometry <==
#
#     Molecular point group: c1
#     Full point group: C_inf_v
#
#     Geometry (in Angstrom), charge = 0, multiplicity = 1:
#
#        Center              X                  Y                   Z               Mass
#     ------------   -----------------  -----------------  -----------------  -----------------
#          LI           0.000000000000     0.000000000000    -0.189816288653     7.016003436600
#          H            0.000000000000     0.000000000000     1.321411644800     1.007825032230
#
#   Running in c1 symmetry.
#
#   Rotational constants: A = ************  B =      8.37613  C =      8.37613 [cm^-1]
#   Rotational constants: A = ************  B = 251109.96997  C = 251109.96997 [MHz]
#   Nuclear repulsion =    1.050491191215352
#
#   Charge       = 0
#   Multiplicity = 1
#   Electrons    = 4
#   Nalpha       = 2
#   Nbeta        = 2
#
#   ==> Algorithm <==
#
#   SCF Algorithm Type is PK.
#   DIIS enabled.
#   MOM disabled.
#   Fractional occupation disabled.
#   Guess Type is READ.
#   Energy threshold   = 1.00e-08
#   Density threshold  = 1.00e-07
#   Integral threshold = 1.00e-12
#
#   ==> Primary Basis <==
#
#   Basis Set: STO-3G
#     Blend: STO-3G
#     Number of shells: 4
#     Number of basis functions: 6
#     Number of Cartesian functions: 6
#     Spherical Harmonics?: true
#     Max angular momentum: 1
#
#    => Loading Basis Set <=
#
#     Name: STO-3G
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1 entry LI         line    31 file /Users/ptolley1/miniforge3/envs/work/share/psi4/basis/sto-3g.gbs
#     atoms 2 entry H          line    19 file /Users/ptolley1/miniforge3/envs/work/share/psi4/basis/sto-3g.gbs
#
#   Reading orbitals from file /tmp/stdout.default.57672.180.npy, no projection.
#
#   ==> Integral Setup <==
#
#   Using in-core PK algorithm.
#    Calculation information:
#       Number of atoms:                   2
#       Number of AO shells:               4
#       Number of primitives:             12
#       Number of atomic orbitals:         6
#       Number of basis functions:         6
#
#       Integral cutoff                 1.00e-12
#       Number of threads:                 1
#
#   Performing in-core PK
#   Using 462 doubles for integral storage.
#   We computed 55 shell quartets total.
#   Whereas there are 55 unique shell quartets.
#
#   ==> DiskJK: Disk-Based J/K Matrices <==
#
#     J tasked:                  Yes
#     K tasked:                  Yes
#     wK tasked:                  No
#     Memory [MiB]:              375
#     Schwarz Cutoff:          1E-12
#
#     OpenMP threads:              1
#
#   Minimum eigenvalue in the overlap matrix is 3.2264993263E-01.
#   Reciprocal condition number of the overlap matrix is 1.8831802777E-01.
#     Using symmetric orthogonalization.
#
#   ==> Pre-Iterations <==
#
#   SCF Guess: Orbitals guess was supplied from a previous computation.
#
#    -------------------------------------------------------
#     Irrep   Nso     Nmo     Nalpha   Nbeta   Ndocc  Nsocc
#    -------------------------------------------------------
#      A          6       6       2       2       2       0
#    -------------------------------------------------------
#     Total       6       6       2       2       2       0
#    -------------------------------------------------------
#
#   ==> Iterations <==
#
#                         Total Energy        Delta E     RMS |[F,P]|
#
#    @RHF iter   0:    -7.86218015718232   -7.86218e+00   5.98566e-04
#    @RHF iter   1:    -7.86338176592717   -1.20161e-03   6.40077e-05 DIIS
#    @RHF iter   2:    -7.86338204953433   -2.83607e-07   1.48687e-05 DIIS
#    @RHF iter   3:    -7.86338208328157   -3.37472e-08   7.06632e-06 DIIS
#    @RHF iter   4:    -7.86338209290021   -9.61864e-09   8.34639e-08 DIIS
#   Energy and wave function converged.
#
#
#   ==> Post-Iterations <==
#
#     Orbital Energies [Eh]
#     ---------------------
#
#     Doubly Occupied:
#
#        1A     -2.347007     2A     -0.292657
#
#     Virtual:
#
#        3A      0.078918     4A      0.163786     5A      0.163786
#        6A      0.571472
#
#     Final Occupation by Irrep:
#               A
#     DOCC [     2 ]
#     NA   [     2 ]
#     NB   [     2 ]
#
#   @RHF Final Energy:    -7.86338209290021
#
#    => Energetics <=
#
#     Nuclear Repulsion Energy =              1.0504911912153521
#     One-Electron Energy =                 -12.5484186203676611
#     Two-Electron Energy =                   3.6345453362520996
#     Total Energy =                         -7.8633820929002098
#
# Computation Completed
#
#
# Properties will be evaluated at   0.000000,   0.000000,   0.000000 [a0]
#
# Properties computed using the SCF density matrix
#
#
#  Multipole Moments:
#
#  ------------------------------------------------------------------------------------
#      Multipole            Electronic (a.u.)      Nuclear  (a.u.)        Total (a.u.)
#  ------------------------------------------------------------------------------------
#
#  L = 1.  Multiply by 2.5417464519 to convert [e a0] to [Debye]
#  Dipole X            :         -0.0000000            0.0000000           -0.0000000
#  Dipole Y            :          0.0000000            0.0000000            0.0000000
#  Dipole Z            :         -3.3248634            1.4210037           -1.9038597
#  Magnitude           :                                                    1.9038597
#
#  ------------------------------------------------------------------------------------
#
# *** tstop() called on CHEMYM0V4HTALT at Thu Oct 12 13:53:12 2023
# Module time:
# 	user time   =       0.03 seconds =       0.00 minutes
# 	system time =       0.00 seconds =       0.00 minutes
# 	total time  =          0 seconds =       0.00 minutes
# Total time:
# 	user time   =     176.60 seconds =       2.94 minutes
# 	system time =       5.71 seconds =       0.10 minutes
# 	total time  =      80493 seconds =    1341.55 minutes
#
# *** tstart() called on CHEMYM0V4HTALT
# *** at Thu Oct 12 13:53:12 2023
#
#
#          ------------------------------------------------------------
#                                    SCF GRAD
#                           Rob Parrish, Justin Turney,
#                        Andy Simmonett, and Alex Sokolov
#          ------------------------------------------------------------
#
#   ==> Geometry <==
#
#     Molecular point group: c1
#     Full point group: C_inf_v
#
#     Geometry (in Angstrom), charge = 0, multiplicity = 1:
#
#        Center              X                  Y                   Z               Mass
#     ------------   -----------------  -----------------  -----------------  -----------------
#          LI           0.000000000000     0.000000000000    -0.189816288653     7.016003436600
#          H            0.000000000000     0.000000000000     1.321411644800     1.007825032230
#
#   Nuclear repulsion =    1.050491191215352
#
#   ==> Basis Set <==
#
#   Basis Set: STO-3G
#     Blend: STO-3G
#     Number of shells: 4
#     Number of basis functions: 6
#     Number of Cartesian functions: 6
#     Spherical Harmonics?: true
#     Max angular momentum: 1
#
#   ==> DirectJKGrad: Integral-Direct SCF Gradients <==
#
#     Gradient:                    1
#     J tasked:                  Yes
#     K tasked:                  Yes
#     wK tasked:                  No
#     Integrals threads:           1
#     Schwarz Cutoff:          1E-12
#
#
#   -Total Gradient:
#      Atom            X                  Y                   Z
#     ------   -----------------  -----------------  -----------------
#        1        0.000000000000    -0.000000000000    -0.000091461210
#        2       -0.000000000000     0.000000000000     0.000091461210
#
#
# *** tstop() called on CHEMYM0V4HTALT at Thu Oct 12 13:53:12 2023
# Module time:
# 	user time   =       0.00 seconds =       0.00 minutes
# 	system time =       0.00 seconds =       0.00 minutes
# 	total time  =          0 seconds =       0.00 minutes
# Total time:
# 	user time   =     176.60 seconds =       2.94 minutes
# 	system time =       5.71 seconds =       0.10 minutes
# 	total time  =      80493 seconds =    1341.55 minutes
#
#     			-----------------------------------------
#
#     			 OPTKING 3.0: for geometry optimizations
#
#     			     By R.A. King, Bethel University
#
#     			        with contributions from
#
#     			    A.V. Copan, J. Cayton, A. Heide
#
#     			-----------------------------------------
#
#
# 	                            ===> Fragment 1 <==
#
# 	 Z (Atomic Numbers)          Masses                          Geom
# 	       3.000000             7.016003          0.00000000  0.00000000 -0.35870080
# 	       1.000000             1.007825          0.00000000  0.00000000  2.49710611
#
# 	 - Coordinate -           - BOHR/RAD -       - ANG/DEG -
# 	 R(1,2)           =         2.855807           1.511228
# Optimizer: Optimization complete!
#
#
# 	        --- Internal Coordinate Step in ANG or DEG, aJ/ANG or AJ/DEG ---
# 	-------------------------------------------------------------------------------
# 	           Coordinate      Previous         Force          Change          New
# 	           ----------      --------        ------          ------        ------
# 	               R(1,2)       1.51123       -0.00075       -0.00043       1.51080
# 	-------------------------------------------------------------------------------
#
# 	                                 ==> Convergence Check <==
#
# 	Measures of convergence in internal coordinates in au.
#
# 	Criteria marked as inactive (o), active & met (*), and active & unmet ( ).
#
# 	----------------------------------------------------------------------------------------------
# 	   Step    Total Energy     Delta E     Max Force     RMS Force      Max Disp      RMS Disp
# 	----------------------------------------------------------------------------------------------
# 	  Convergence Criteria     1.00e-06 *    3.00e-04 *             o    1.20e-03 *             o
# 	----------------------------------------------------------------------------------------------
# 	     4      -7.86338209   -2.94e-05      9.15e-05 *    9.15e-05 o    8.16e-04 *    8.16e-04 o  ~
# 	----------------------------------------------------------------------------------------------
#
# Next Geometry in Ang
# 	Fragment 1 (Ang)
#
# 	   Li   0.0000000000   0.0000000000  -0.1896004272
# 	    H   0.0000000000   0.0000000000   1.3211957834
#
#
#     Final optimized geometry and variables:
#     Molecular point group: c1
#     Full point group: C_inf_v
#
#     Geometry (in Angstrom), charge = 0, multiplicity = 1:
#
#     LI
#     H             1    1.511228

# %%
# options dictionary for the psi4 calculation
options_dict = {'basis': 'sto-3g',
               'save_jk': True, 
               'scf_type': 'pk',
               'e_convergence' : 1e-8,
               'd_convergence' : 1e-7
               }

# set the options
psi4.set_options(options_dict)

# first set the coordinates in guess_string as the molecule's geometry 
mol = psi4.geometry(guess_string)

# now capture the psi4 geometry data with the guess coordinates
guess_geometry_string = psi4.core.Molecule.create_psi4_string_from_molecule(mol)

# run the geometry optimization
psi4.optimize("HF")

opt_geometry = mol.geometry()

# capture the psi4 geometry data from the optimization
opt_geometry_string = psi4.core.Molecule.create_psi4_string_from_molecule(mol)

# run excited-state calculations - get first 5 excited states
n_states = 1

# run psi4 TDSCF at same level of theory as geometry optimization
psi4_rhf_e, wfn = psi4.frequency("CAM-b3lyp/sto-3g", return_wfn=True, molecule=mol,maxiter=50)
# Out:
# Scratch directory: /tmp/
# gradient() will perform analytic gradient computation.
#    => Libint2 <=
#
#     Primary   basis highest AM E, G, H:  5, 4, 3
#     Auxiliary basis highest AM E, G, H:  6, 5, 4
#     Onebody   basis highest AM E, G, H:  6, 5, 4
#     Solid Harmonics ordering:            gaussian
#
# *** tstart() called on CHEMYM0V4HTALT
# *** at Thu Oct 12 13:53:13 2023
#
#    => Loading Basis Set <=
#
#     Name: STO-3G
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1 entry LI         line    31 file /Users/ptolley1/miniforge3/envs/work/share/psi4/basis/sto-3g.gbs
#     atoms 2 entry H          line    19 file /Users/ptolley1/miniforge3/envs/work/share/psi4/basis/sto-3g.gbs
#
#
#          ---------------------------------------------------------
#                                    SCF
#                by Justin Turney, Rob Parrish, Andy Simmonett
#                           and Daniel G. A. Smith
#                               RHF Reference
#                         1 Threads,    500 MiB Core
#          ---------------------------------------------------------
#
#   ==> Geometry <==
#
#     Molecular point group: c1
#     Full point group: C_inf_v
#
#     Geometry (in Angstrom), charge = 0, multiplicity = 1:
#
#        Center              X                  Y                   Z               Mass
#     ------------   -----------------  -----------------  -----------------  -----------------
#          LI           0.000000000000     0.000000000000    -0.189816288659     7.016003436600
#          H            0.000000000000     0.000000000000     1.321411644841     1.007825032230
#
#   Running in c1 symmetry.
#
#   Rotational constants: A = ************  B =      8.37613  C =      8.37613 [cm^-1]
#   Rotational constants: A = ************  B = 251109.96995  C = 251109.96995 [MHz]
#   Nuclear repulsion =    1.050491191182048
#
#   Charge       = 0
#   Multiplicity = 1
#   Electrons    = 4
#   Nalpha       = 2
#   Nbeta        = 2
#
#   ==> Algorithm <==
#
#   SCF Algorithm Type is PK.
#   DIIS enabled.
#   MOM disabled.
#   Fractional occupation disabled.
#   Guess Type is SAD.
#   Energy threshold   = 1.00e-08
#   Density threshold  = 1.00e-07
#   Integral threshold = 1.00e-12
#
#   ==> Primary Basis <==
#
#   Basis Set: STO-3G
#     Blend: STO-3G
#     Number of shells: 4
#     Number of basis functions: 6
#     Number of Cartesian functions: 6
#     Spherical Harmonics?: true
#     Max angular momentum: 1
#
#   ==> Integral Setup <==
#
#   Using in-core PK algorithm.
#    Calculation information:
#       Number of atoms:                   2
#       Number of AO shells:               4
#       Number of primitives:             12
#       Number of atomic orbitals:         6
#       Number of basis functions:         6
#
#       Integral cutoff                 1.00e-12
#       Number of threads:                 1
#
#   Performing in-core PK
#   Using 462 doubles for integral storage.
#   We computed 55 shell quartets total.
#   Whereas there are 55 unique shell quartets.
#
#   ==> DiskJK: Disk-Based J/K Matrices <==
#
#     J tasked:                  Yes
#     K tasked:                  Yes
#     wK tasked:                  No
#     Memory [MiB]:              375
#     Schwarz Cutoff:          1E-12
#
#     OpenMP threads:              1
#
#   Minimum eigenvalue in the overlap matrix is 3.2264993264E-01.
#   Reciprocal condition number of the overlap matrix is 1.8831802778E-01.
#     Using symmetric orthogonalization.
#
#   ==> Pre-Iterations <==
#
#   SCF Guess: Superposition of Atomic Densities via on-the-fly atomic UHF (no occupation information).
#
#    -------------------------
#     Irrep   Nso     Nmo
#    -------------------------
#      A          6       6
#    -------------------------
#     Total       6       6
#    -------------------------
#
#   ==> Iterations <==
#
#                         Total Energy        Delta E     RMS |[F,P]|
#
#    @RHF iter SAD:    -7.45628335632661   -7.45628e+00   0.00000e+00
#    @RHF iter   1:    -7.84681506029884   -3.90532e-01   1.81969e-02 ADIIS/DIIS
#    @RHF iter   2:    -7.86300373404697   -1.61887e-02   1.83421e-03 ADIIS/DIIS
#    @RHF iter   3:    -7.86331871880617   -3.14985e-04   5.63440e-04 ADIIS/DIIS
#    @RHF iter   4:    -7.86338197385206   -6.32550e-05   2.99339e-05 DIIS
#    @RHF iter   5:    -7.86338209269962   -1.18848e-07   1.40058e-06 DIIS
#    @RHF iter   6:    -7.86338209290073   -2.01113e-10   2.16720e-08 DIIS
#   Energy and wave function converged.
#
#
#   ==> Post-Iterations <==
#
#     Orbital Energies [Eh]
#     ---------------------
#
#     Doubly Occupied:
#
#        1A     -2.347007     2A     -0.292657
#
#     Virtual:
#
#        3A      0.078918     4A      0.163786     5A      0.163786
#        6A      0.571472
#
#     Final Occupation by Irrep:
#               A
#     DOCC [     2 ]
#     NA   [     2 ]
#     NB   [     2 ]
#
#   @RHF Final Energy:    -7.86338209290073
#
#    => Energetics <=
#
#     Nuclear Repulsion Energy =              1.0504911911820483
#     One-Electron Energy =                 -12.5484185792001970
#     Two-Electron Energy =                   3.6345452951174133
#     Total Energy =                         -7.8633820929007348
#
# Computation Completed
#
#
# Properties will be evaluated at   0.000000,   0.000000,   0.000000 [a0]
#
# Properties computed using the SCF density matrix
#
#
#  Multipole Moments:
#
#  ------------------------------------------------------------------------------------
#      Multipole            Electronic (a.u.)      Nuclear  (a.u.)        Total (a.u.)
#  ------------------------------------------------------------------------------------
#
#  L = 1.  Multiply by 2.5417464519 to convert [e a0] to [Debye]
#  Dipole X            :          0.0000000            0.0000000            0.0000000
#  Dipole Y            :         -0.0000000            0.0000000           -0.0000000
#  Dipole Z            :         -3.3248634            1.4210037           -1.9038597
#  Magnitude           :                                                    1.9038597
#
#  ------------------------------------------------------------------------------------
# Optimizer: Optimization complete!
#
# *** tstop() called on CHEMYM0V4HTALT at Thu Oct 12 13:53:13 2023
# Module time:
# 	user time   =       0.06 seconds =       0.00 minutes
# 	system time =       0.00 seconds =       0.00 minutes
# 	total time  =          0 seconds =       0.00 minutes
# Total time:
# 	user time   =     176.85 seconds =       2.95 minutes
# 	system time =       5.72 seconds =       0.10 minutes
# 	total time  =      80494 seconds =    1341.57 minutes
#
# *** tstart() called on CHEMYM0V4HTALT
# *** at Thu Oct 12 13:53:13 2023
#
#
#          ------------------------------------------------------------
#                                    SCF GRAD
#                           Rob Parrish, Justin Turney,
#                        Andy Simmonett, and Alex Sokolov
#          ------------------------------------------------------------
#
#   ==> Geometry <==
#
#     Molecular point group: c1
#     Full point group: C_inf_v
#
#     Geometry (in Angstrom), charge = 0, multiplicity = 1:
#
#        Center              X                  Y                   Z               Mass
#     ------------   -----------------  -----------------  -----------------  -----------------
#          LI           0.000000000000     0.000000000000    -0.189816288659     7.016003436600
#          H            0.000000000000     0.000000000000     1.321411644841     1.007825032230
#
#   Nuclear repulsion =    1.050491191182048
#
#   ==> Basis Set <==
#
#   Basis Set: STO-3G
#     Blend: STO-3G
#     Number of shells: 4
#     Number of basis functions: 6
#     Number of Cartesian functions: 6
#     Spherical Harmonics?: true
#     Max angular momentum: 1
#
#   ==> DirectJKGrad: Integral-Direct SCF Gradients <==
#
#     Gradient:                    1
#     J tasked:                  Yes
#     K tasked:                  Yes
#     wK tasked:                  No
#     Integrals threads:           1
#     Schwarz Cutoff:          1E-12
#
#
#   -Total Gradient:
#      Atom            X                  Y                   Z
#     ------   -----------------  -----------------  -----------------
#        1       -0.000000000000     0.000000000000    -0.000091459401
#        2        0.000000000000    -0.000000000000     0.000091459401
#
#
# *** tstop() called on CHEMYM0V4HTALT at Thu Oct 12 13:53:13 2023
# Module time:
# 	user time   =       0.00 seconds =       0.00 minutes
# 	system time =       0.00 seconds =       0.00 minutes
# 	total time  =          0 seconds =       0.00 minutes
# Total time:
# 	user time   =     176.85 seconds =       2.95 minutes
# 	system time =       5.72 seconds =       0.10 minutes
# 	total time  =      80494 seconds =    1341.57 minutes
#
#     			-----------------------------------------
#
#     			 OPTKING 3.0: for geometry optimizations
#
#     			     By R.A. King, Bethel University
#
#     			        with contributions from
#
#     			    A.V. Copan, J. Cayton, A. Heide
#
#     			-----------------------------------------
#
#
# 	                            ===> Fragment 1 <==
#
# 	 Z (Atomic Numbers)          Masses                          Geom
# 	       3.000000             7.016003          0.00000000  0.00000000 -0.35870080
# 	       1.000000             1.007825          0.00000000  0.00000000  2.49710611
#
# 	 - Coordinate -           - BOHR/RAD -       - ANG/DEG -
# 	 R(1,2)           =         2.855807           1.511228
#
#
# 	        --- Internal Coordinate Step in ANG or DEG, aJ/ANG or AJ/DEG ---
# 	-------------------------------------------------------------------------------
# 	           Coordinate      Previous         Force          Change          New
# 	           ----------      --------        ------          ------        ------
# 	               R(1,2)       1.51123       -0.00075       -0.00044       1.51079
# 	-------------------------------------------------------------------------------
#
# 	                                 ==> Convergence Check <==
#
# 	Measures of convergence in internal coordinates in au.
#
# 	Criteria marked as inactive (o), active & met (*), and active & unmet ( ).
#
# 	----------------------------------------------------------------------------------------------
# 	   Step    Total Energy     Delta E     Max Force     RMS Force      Max Disp      RMS Disp
# 	----------------------------------------------------------------------------------------------
# 	  Convergence Criteria     1.00e-06 *    3.00e-04 *             o    1.20e-03 *             o
# 	----------------------------------------------------------------------------------------------
# 	     1      -7.86338209   -7.86e+00      9.15e-05 *    9.15e-05 o    8.28e-04 *    8.28e-04 o  ~
# 	----------------------------------------------------------------------------------------------
#
# Next Geometry in Ang
# 	Fragment 1 (Ang)
#
# 	   Li   0.0000000000   0.0000000000  -0.1895972339
# 	    H   0.0000000000   0.0000000000   1.3211925901
#
#
#     Final optimized geometry and variables:
#     Molecular point group: c1
#     Full point group: C_inf_v
#
#     Geometry (in Angstrom), charge = 0, multiplicity = 1:
#
#     LI
#     H             1    1.511228
#
#
#          ----------------------------------------------------------
#                                    FINDIF
#                      R. A. King and Jonathon Misiewicz
#          ----------------------------------------------------------
#
#   Using finite-differences of gradients to determine vibrational frequencies and
#   normal modes. Resulting frequencies are only valid at stationary points.
#     Generating geometries for use with 3-point formula.
#     Displacement size will be 5.00e-03.
#     Number of atoms is 2.
#     Number of irreps is 1.
#     Number of SALCs is 3.
#     Translations projected? 1. Rotations projected? 0.
#     Index of SALCs per irrep:
#       1 :  0  1  2
#     Number of SALCs per irrep:
#       Irrep 1: 3
#     Number of geometries (including reference) is 7.
#     Number of displacements per irrep:
#       Irrep 1: 6
#  7 displacements needed ...
#
#   //>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>//
#   //    FiniteDifference Computations  //
#   //<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<//
#     -----------------------------------------------------------------------
#           Psi4: An Open-Source Ab Initio Electronic Structure Package
#                                Psi4 1.8 release
#
#                          Git: Rev {} zzzzzzz
#
#
#     D. G. A. Smith, L. A. Burns, A. C. Simmonett, R. M. Parrish,
#     M. C. Schieber, R. Galvelis, P. Kraus, H. Kruse, R. Di Remigio,
#     A. Alenaizan, A. M. James, S. Lehtola, J. P. Misiewicz, M. Scheurer,
#     R. A. Shaw, J. B. Schriber, Y. Xie, Z. L. Glick, D. A. Sirianni,
#     J. S. O'Brien, J. M. Waldrop, A. Kumar, E. G. Hohenstein,
#     B. P. Pritchard, B. R. Brooks, H. F. Schaefer III, A. Yu. Sokolov,
#     K. Patkowski, A. E. DePrince III, U. Bozkaya, R. A. King,
#     F. A. Evangelista, J. M. Turney, T. D. Crawford, C. D. Sherrill,
#     J. Chem. Phys. 152(18) 184108 (2020). https://doi.org/10.1063/5.0006002
#
#                             Additional Code Authors
#     E. T. Seidl, C. L. Janssen, E. F. Valeev, M. L. Leininger,
#     J. F. Gonthier, R. M. Richard, H. R. McAlexander, M. Saitow, X. Wang,
#     P. Verma, M. H. Lechner, A. Jiang, S. Behnle, A. G. Heide,
#     M. F. Herbst, and D. L. Poole
#
#              Previous Authors, Complete List of Code Contributors,
#                        and Citations for Specific Modules
#     https://github.com/psi4/psi4/blob/master/codemeta.json
#     https://github.com/psi4/psi4/graphs/contributors
#     http://psicode.org/psi4manual/master/introduction.html#citing-psifour
#
#     -----------------------------------------------------------------------
#
#
#     Psi4 started on: Wednesday, 11 October 2023 03:31PM
#
#     Process ID: 57672
#     Host:       CHEMYM0V4HTALT
#     PSIDATADIR: /Users/ptolley1/miniforge3/envs/work/share/psi4
#     Memory:     500.0 MiB
#     Threads:    1
#
#   ==> Input QCSchema <==
#
# --------------------------------------------------------------------------
# {'driver': 'gradient',
#  'extras': {'psiapi': True, 'wfn_qcvars_only': True},
#  'id': None,
#  'keywords': {'D_CONVERGENCE': 1e-07,
#               'E_CONVERGENCE': 1e-08,
#               'PARENT_SYMMETRY': 'C1',
#               'SAVE_JK': 1,
#               'SCF_TYPE': 'PK',
#               'SCF__INTS_TOLERANCE': 1e-12,
#               'function_kwargs': {}},
#  'model': {'basis': 'sto-3g', 'method': 'cam-b3lyp'},
#  'molecule': {'atom_labels': ['', ''],
#               'atomic_numbers': [3, 1],
#               'fix_com': True,
#               'fix_orientation': True,
#               'fix_symmetry': 'c1',
#               'fragment_charges': [0.0],
#               'fragment_multiplicities': [1],
#               'fragments': [[0, 1]],
#               'geometry': [0.0, 0.0, -0.35870079971559743, 0.0, 0.0, 2.497106107740997],
#               'mass_numbers': [7, 1],
#               'masses': [7.0160034366, 1.00782503223],
#               'molecular_charge': 0.0,
#               'molecular_multiplicity': 1,
#               'name': 'HLi',
#               'provenance': {'creator': 'QCElemental',
#                              'routine': 'qcelemental.molparse.from_string',
#                              'version': 'v0.25.1'},
#               'real': [True, True],
#               'schema_name': 'qcschema_molecule',
#               'schema_version': 2,
#               'symbols': ['Li', 'H'],
#               'validated': True},
#  'protocols': {'stdout': True},
#  'provenance': {'creator': 'QCElemental', 'routine': 'qcelemental.models.results', 'version': 'v0.25.1'},
#  'schema_name': 'qcschema_input',
#  'schema_version': 1}
# --------------------------------------------------------------------------
#
# Scratch directory: /tmp/
# gradient() will perform analytic gradient computation.
#    => Libint2 <=
#
#     Primary   basis highest AM E, G, H:  5, 4, 3
#     Auxiliary basis highest AM E, G, H:  6, 5, 4
#     Onebody   basis highest AM E, G, H:  6, 5, 4
#     Solid Harmonics ordering:            gaussian
#
# *** tstart() called on CHEMYM0V4HTALT
# *** at Thu Oct 12 13:53:13 2023
#
#    => Loading Basis Set <=
#
#     Name: STO-3G
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1 entry LI         line    31 file /Users/ptolley1/miniforge3/envs/work/share/psi4/basis/sto-3g.gbs
#     atoms 2 entry H          line    19 file /Users/ptolley1/miniforge3/envs/work/share/psi4/basis/sto-3g.gbs
#
#
#          ---------------------------------------------------------
#                                    SCF
#                by Justin Turney, Rob Parrish, Andy Simmonett
#                           and Daniel G. A. Smith
#                               RKS Reference
#                         1 Threads,    500 MiB Core
#          ---------------------------------------------------------
#
#   ==> Geometry <==
#
#     Molecular point group: c1
#     Full point group: C_inf_v
#
#     Geometry (in Bohr), charge = 0, multiplicity = 1:
#
#        Center              X                  Y                   Z               Mass
#     ------------   -----------------  -----------------  -----------------  -----------------
#          LI           0.000000000000     0.000000000000    -0.358700799716     7.016003436600
#          H            0.000000000000     0.000000000000     2.497106107741     1.007825032230
#
#   Running in c1 symmetry.
#
#   Rotational constants: A = ************  B =      8.37613  C =      8.37613 [cm^-1]
#   Rotational constants: A = ************  B = 251109.96995  C = 251109.96995 [MHz]
#   Nuclear repulsion =    1.050491191182048
#
#   Charge       = 0
#   Multiplicity = 1
#   Electrons    = 4
#   Nalpha       = 2
#   Nbeta        = 2
#
#   ==> Algorithm <==
#
#   SCF Algorithm Type is PK.
#   DIIS enabled.
#   MOM disabled.
#   Fractional occupation disabled.
#   Guess Type is SAD.
#   Energy threshold   = 1.00e-08
#   Density threshold  = 1.00e-07
#   Integral threshold = 1.00e-12
#
#   ==> Primary Basis <==
#
#   Basis Set: STO-3G
#     Blend: STO-3G
#     Number of shells: 4
#     Number of basis functions: 6
#     Number of Cartesian functions: 6
#     Spherical Harmonics?: true
#     Max angular momentum: 1
#
#   ==> DFT Potential <==
#
#    => LibXC <=
#
#     Version 6.1.0
#     S. Lehtola, C. Steigemann, M. J.T. Oliveira, and M. A.L. Marques.,  SoftwareX 7, 1–5 (2018) (10.1016/j.softx.2017.11.002)
#
#    => Composite Functional: CAM-B3LYP <=
#
#     CAM-B3LYP Hyb-GGA Exchange-Correlation Functional
#
#     T. Yanai, D. P. Tew, and N. C. Handy.,  Chem. Phys. Lett. 393, 51 (2004) (10.1016/j.cplett.2004.06.011)
#
#     Deriv               =              1
#     GGA                 =           TRUE
#     Meta                =          FALSE
#
#     Exchange Hybrid     =           TRUE
#     MP2 Hybrid          =          FALSE
#
#    => Exchange Functionals <=
#
#     0.3500         Becke 88 [omega = 0.3300]
#     0.4600   Short-range recipe for B88 functional - erf [omega = 0.3300]
#
#    => Exact (HF) Exchange <=
#
#     0.4600            HF,LR [omega = 0.3300]
#     0.1900               HF
#
#    => Correlation Functionals <=
#
#     0.1900   Vosko, Wilk & Nusair (VWN5)
#     0.8100   Lee, Yang & Parr
#
#    => LibXC Density Thresholds  <==
#
#     XC_HYB_GGA_XC_CAM_B3LYP:  1.00E-14
#
#    => Molecular Quadrature <=
#
#     Radial Scheme          =       TREUTLER
#     Pruning Scheme         =           NONE
#     Nuclear Scheme         =       TREUTLER
#
#     Blocking Scheme        =         OCTREE
#     BS radius alpha        =              1
#     Pruning alpha          =              1
#     Radial Points          =             75
#     Spherical Points       =            302
#     Total Points           =          43148
#     Total Blocks           =            398
#     Max Points             =            253
#     Max Functions          =              6
#     Weights Tolerance      =       1.00E-15
#
#   ==> Integral Setup <==
#
#   Using in-core PK algorithm.
#    Calculation information:
#       Number of atoms:                   2
#       Number of AO shells:               4
#       Number of primitives:             12
#       Number of atomic orbitals:         6
#       Number of basis functions:         6
#
#       Integral cutoff                 1.00e-12
#       Number of threads:                 1
#
#   Performing in-core PK
#   Using 693 doubles for integral storage.
#   We computed 55 shell quartets total.
#   Whereas there are 55 unique shell quartets.
#
#   Computing range-separated integrals for PK
#   We computed 55 wK shell quartets total.
#   Whereas there are 55 wK unique shell quartets.
#
#   ==> DiskJK: Disk-Based J/K Matrices <==
#
#     J tasked:                  Yes
#     K tasked:                  Yes
#     wK tasked:                 Yes
#     Omega:               3.300E-01
#     Memory [MiB]:              367
#     Schwarz Cutoff:          1E-12
#
#     OpenMP threads:              1
#
#   Cached 100.0% of DFT collocation blocks in 0.008 [GiB].
#
#   Minimum eigenvalue in the overlap matrix is 3.2264993264E-01.
#   Reciprocal condition number of the overlap matrix is 1.8831802778E-01.
#     Using symmetric orthogonalization.
#
#   ==> Pre-Iterations <==
#
#   SCF Guess: Superposition of Atomic Densities via on-the-fly atomic UHF (no occupation information).
#
#    -------------------------
#     Irrep   Nso     Nmo
#    -------------------------
#      A          6       6
#    -------------------------
#     Total       6       6
#    -------------------------
#
#   ==> Iterations <==
#
#                         Total Energy        Delta E     RMS |[F,P]|
#
#    @RKS iter SAD:    -7.61705601065056   -7.61706e+00   0.00000e+00
#    @RKS iter   1:    -7.91855703949983   -3.01501e-01   1.97273e-02 ADIIS/DIIS
#    @RKS iter   2:    -7.93637202018658   -1.78150e-02   4.85900e-03 ADIIS/DIIS
#    @RKS iter   3:    -7.93741548278377   -1.04346e-03   4.11591e-04 ADIIS/DIIS
#    @RKS iter   4:    -7.93744884806881   -3.33653e-05   1.06379e-04 ADIIS/DIIS
#    @RKS iter   5:    -7.93745099718999   -2.14912e-06   7.31909e-06 DIIS
#    @RKS iter   6:    -7.93745100430205   -7.11206e-09   4.28957e-08 DIIS
#   Energy and wave function converged.
#
#
#   ==> Post-Iterations <==
#
#    Electrons on quadrature grid:
#       Ntotal   =    4.0000008216 ; deviation = 8.216e-07
#
#     Orbital Energies [Eh]
#     ---------------------
#
#     Doubly Occupied:
#
#        1A     -1.966429     2A     -0.240423
#
#     Virtual:
#
#        3A      0.021323     4A      0.093416     5A      0.093416
#        6A      0.449481
#
#     Final Occupation by Irrep:
#               A
#     DOCC [     2 ]
#     NA   [     2 ]
#     NB   [     2 ]
#
#   @RKS Final Energy:    -7.93745100430205
#
#    => Energetics <=
#
#     Nuclear Repulsion Energy =              1.0504911911820485
#     One-Electron Energy =                 -12.5386982138331167
#     Two-Electron Energy =                   5.0874225035940830
#     DFT Exchange-Correlation Energy =      -1.5366664852450649
#     Empirical Dispersion Energy =           0.0000000000000000
#     VV10 Nonlocal Energy =                  0.0000000000000000
#     Total Energy =                         -7.9374510043020496
#
# Computation Completed
#
#
# Properties will be evaluated at   0.000000,   0.000000,   0.000000 [a0]
#
# Properties computed using the SCF density matrix
#
#
#  Multipole Moments:
#
#  ------------------------------------------------------------------------------------
#      Multipole            Electronic (a.u.)      Nuclear  (a.u.)        Total (a.u.)
#  ------------------------------------------------------------------------------------
#
#  L = 1.  Multiply by 2.5417464519 to convert [e a0] to [Debye]
#  Dipole X            :          0.0000000            0.0000000            0.0000000
#  Dipole Y            :         -0.0000000            0.0000000           -0.0000000
#  Dipole Z            :         -3.2953429            1.4210037           -1.8743392
#  Magnitude           :                                                    1.8743392
#
#  ------------------------------------------------------------------------------------
#
# *** tstop() called on CHEMYM0V4HTALT at Thu Oct 12 13:53:13 2023
# Module time:
# 	user time   =       0.27 seconds =       0.00 minutes
# 	system time =       0.02 seconds =       0.00 minutes
# 	total time  =          0 seconds =       0.00 minutes
# Total time:
# 	user time   =     177.17 seconds =       2.95 minutes
# 	system time =       5.74 seconds =       0.10 minutes
# 	total time  =      80494 seconds =    1341.57 minutes
#
# *** tstart() called on CHEMYM0V4HTALT
# *** at Thu Oct 12 13:53:13 2023
#
#
#          ------------------------------------------------------------
#                                    SCF GRAD
#                           Rob Parrish, Justin Turney,
#                        Andy Simmonett, and Alex Sokolov
#          ------------------------------------------------------------
#
#   ==> Geometry <==
#
#     Molecular point group: c1
#     Full point group: C_inf_v
#
#     Geometry (in Bohr), charge = 0, multiplicity = 1:
#
#        Center              X                  Y                   Z               Mass
#     ------------   -----------------  -----------------  -----------------  -----------------
#          LI           0.000000000000     0.000000000000    -0.358700799716     7.016003436600
#          H            0.000000000000     0.000000000000     2.497106107741     1.007825032230
#
#   Nuclear repulsion =    1.050491191182048
#
#   ==> Basis Set <==
#
#   Basis Set: STO-3G
#     Blend: STO-3G
#     Number of shells: 4
#     Number of basis functions: 6
#     Number of Cartesian functions: 6
#     Spherical Harmonics?: true
#     Max angular momentum: 1
#
#   ==> DirectJKGrad: Integral-Direct SCF Gradients <==
#
#     Gradient:                    1
#     J tasked:                  Yes
#     K tasked:                  Yes
#     wK tasked:                 Yes
#     Omega:               3.300E-01
#     Integrals threads:           1
#     Schwarz Cutoff:          1E-12
#
#   ==> DFT Potential <==
#
#    => LibXC <=
#
#     Version 6.1.0
#     S. Lehtola, C. Steigemann, M. J.T. Oliveira, and M. A.L. Marques.,  SoftwareX 7, 1–5 (2018) (10.1016/j.softx.2017.11.002)
#
#    => Composite Functional: CAM-B3LYP <=
#
#     CAM-B3LYP Hyb-GGA Exchange-Correlation Functional
#
#     T. Yanai, D. P. Tew, and N. C. Handy.,  Chem. Phys. Lett. 393, 51 (2004) (10.1016/j.cplett.2004.06.011)
#
#     Deriv               =              1
#     GGA                 =           TRUE
#     Meta                =          FALSE
#
#     Exchange Hybrid     =           TRUE
#     MP2 Hybrid          =          FALSE
#
#    => Exchange Functionals <=
#
#     0.3500         Becke 88 [omega = 0.3300]
#     0.4600   Short-range recipe for B88 functional - erf [omega = 0.3300]
#
#    => Exact (HF) Exchange <=
#
#     0.4600            HF,LR [omega = 0.3300]
#     0.1900               HF
#
#    => Correlation Functionals <=
#
#     0.1900   Vosko, Wilk & Nusair (VWN5)
#     0.8100   Lee, Yang & Parr
#
#    => LibXC Density Thresholds  <==
#
#     XC_HYB_GGA_XC_CAM_B3LYP:  1.00E-14
#
#    => Molecular Quadrature <=
#
#     Radial Scheme          =       TREUTLER
#     Pruning Scheme         =           NONE
#     Nuclear Scheme         =       TREUTLER
#
#     Blocking Scheme        =         OCTREE
#     BS radius alpha        =              1
#     Pruning alpha          =              1
#     Radial Points          =             75
#     Spherical Points       =            302
#     Total Points           =          43148
#     Total Blocks           =            398
#     Max Points             =            253
#     Max Functions          =              6
#     Weights Tolerance      =       1.00E-15
#
#
#   -Total Gradient:
#      Atom            X                  Y                   Z
#     ------   -----------------  -----------------  -----------------
#        1        0.000000000000    -0.000000000000     0.001640678818
#        2       -0.000000000000    -0.000000000000    -0.001641553552
#
#
# *** tstop() called on CHEMYM0V4HTALT at Thu Oct 12 13:53:13 2023
# Module time:
# 	user time   =       0.04 seconds =       0.00 minutes
# 	system time =       0.00 seconds =       0.00 minutes
# 	total time  =          0 seconds =       0.00 minutes
# Total time:
# 	user time   =     177.21 seconds =       2.95 minutes
# 	system time =       5.74 seconds =       0.10 minutes
# 	total time  =      80494 seconds =    1341.57 minutes
#
#     Psi4 stopped on: Thursday, 12 October 2023 01:53PM
#     Psi4 wall time for execution: 0:00:00.35
#     -----------------------------------------------------------------------
#           Psi4: An Open-Source Ab Initio Electronic Structure Package
#                                Psi4 1.8 release
#
#                          Git: Rev {} zzzzzzz
#
#
#     D. G. A. Smith, L. A. Burns, A. C. Simmonett, R. M. Parrish,
#     M. C. Schieber, R. Galvelis, P. Kraus, H. Kruse, R. Di Remigio,
#     A. Alenaizan, A. M. James, S. Lehtola, J. P. Misiewicz, M. Scheurer,
#     R. A. Shaw, J. B. Schriber, Y. Xie, Z. L. Glick, D. A. Sirianni,
#     J. S. O'Brien, J. M. Waldrop, A. Kumar, E. G. Hohenstein,
#     B. P. Pritchard, B. R. Brooks, H. F. Schaefer III, A. Yu. Sokolov,
#     K. Patkowski, A. E. DePrince III, U. Bozkaya, R. A. King,
#     F. A. Evangelista, J. M. Turney, T. D. Crawford, C. D. Sherrill,
#     J. Chem. Phys. 152(18) 184108 (2020). https://doi.org/10.1063/5.0006002
#
#                             Additional Code Authors
#     E. T. Seidl, C. L. Janssen, E. F. Valeev, M. L. Leininger,
#     J. F. Gonthier, R. M. Richard, H. R. McAlexander, M. Saitow, X. Wang,
#     P. Verma, M. H. Lechner, A. Jiang, S. Behnle, A. G. Heide,
#     M. F. Herbst, and D. L. Poole
#
#              Previous Authors, Complete List of Code Contributors,
#                        and Citations for Specific Modules
#     https://github.com/psi4/psi4/blob/master/codemeta.json
#     https://github.com/psi4/psi4/graphs/contributors
#     http://psicode.org/psi4manual/master/introduction.html#citing-psifour
#
#     -----------------------------------------------------------------------
#
#
#     Psi4 started on: Wednesday, 11 October 2023 03:31PM
#
#     Process ID: 57672
#     Host:       CHEMYM0V4HTALT
#     PSIDATADIR: /Users/ptolley1/miniforge3/envs/work/share/psi4
#     Memory:     500.0 MiB
#     Threads:    1
#
#   ==> Input QCSchema <==
#
# --------------------------------------------------------------------------
# {'driver': 'gradient',
#  'extras': {'psiapi': True, 'wfn_qcvars_only': True},
#  'id': None,
#  'keywords': {'D_CONVERGENCE': 1e-07,
#               'E_CONVERGENCE': 1e-08,
#               'PARENT_SYMMETRY': 'C1',
#               'SAVE_JK': 1,
#               'SCF_TYPE': 'PK',
#               'SCF__INTS_TOLERANCE': 1e-12,
#               'function_kwargs': {'write_orbitals': False}},
#  'model': {'basis': 'sto-3g', 'method': 'cam-b3lyp'},
#  'molecule': {'atom_labels': ['', ''],
#               'atomic_numbers': [3, 1],
#               'fix_com': True,
#               'fix_orientation': True,
#               'fix_symmetry': 'c1',
#               'fragment_charges': [0.0],
#               'fragment_multiplicities': [1],
#               'fragments': [[0, 1]],
#               'geometry': [-0.0006690011439782615, 0.0, -0.35870079971559743, 0.0046572710293324455, 0.0,
#                            2.497106107740997],
#               'mass_numbers': [7, 1],
#               'masses': [7.0160034366, 1.00782503223],
#               'molecular_charge': 0.0,
#               'molecular_multiplicity': 1,
#               'name': 'HLi',
#               'provenance': {'creator': 'QCElemental',
#                              'routine': 'qcelemental.molparse.from_string',
#                              'version': 'v0.25.1'},
#               'real': [True, True],
#               'schema_name': 'qcschema_molecule',
#               'schema_version': 2,
#               'symbols': ['Li', 'H'],
#               'validated': True},
#  'protocols': {'stdout': True},
#  'provenance': {'creator': 'QCElemental', 'routine': 'qcelemental.models.results', 'version': 'v0.25.1'},
#  'schema_name': 'qcschema_input',
#  'schema_version': 1}
# --------------------------------------------------------------------------
#
# Scratch directory: /tmp/
# gradient() will perform analytic gradient computation.
#    => Libint2 <=
#
#     Primary   basis highest AM E, G, H:  5, 4, 3
#     Auxiliary basis highest AM E, G, H:  6, 5, 4
#     Onebody   basis highest AM E, G, H:  6, 5, 4
#     Solid Harmonics ordering:            gaussian
#
# *** tstart() called on CHEMYM0V4HTALT
# *** at Thu Oct 12 13:53:13 2023
#
#    => Loading Basis Set <=
#
#     Name: STO-3G
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1 entry LI         line    31 file /Users/ptolley1/miniforge3/envs/work/share/psi4/basis/sto-3g.gbs
#     atoms 2 entry H          line    19 file /Users/ptolley1/miniforge3/envs/work/share/psi4/basis/sto-3g.gbs
#
#
#          ---------------------------------------------------------
#                                    SCF
#                by Justin Turney, Rob Parrish, Andy Simmonett
#                           and Daniel G. A. Smith
#                               RKS Reference
#                         1 Threads,    500 MiB Core
#          ---------------------------------------------------------
#
#   ==> Geometry <==
#
#     Molecular point group: c1
#     Full point group: C_inf_v
#
#     Geometry (in Bohr), charge = 0, multiplicity = 1:
#
#        Center              X                  Y                   Z               Mass
#     ------------   -----------------  -----------------  -----------------  -----------------
#          LI          -0.000669001144     0.000000000000    -0.358700799716     7.016003436600
#          H            0.004657271029     0.000000000000     2.497106107741     1.007825032230
#
#   Running in c1 symmetry.
#
#   Rotational constants: A = ************  B =      8.37610  C =      8.37610 [cm^-1]
#   Rotational constants: A = ************  B = 251109.09647  C = 251109.09647 [MHz]
#   Nuclear repulsion =    1.050489364132534
#
#   Charge       = 0
#   Multiplicity = 1
#   Electrons    = 4
#   Nalpha       = 2
#   Nbeta        = 2
#
#   ==> Algorithm <==
#
#   SCF Algorithm Type is PK.
#   DIIS enabled.
#   MOM disabled.
#   Fractional occupation disabled.
#   Guess Type is SAD.
#   Energy threshold   = 1.00e-08
#   Density threshold  = 1.00e-07
#   Integral threshold = 1.00e-12
#
#   ==> Primary Basis <==
#
#   Basis Set: STO-3G
#     Blend: STO-3G
#     Number of shells: 4
#     Number of basis functions: 6
#     Number of Cartesian functions: 6
#     Spherical Harmonics?: true
#     Max angular momentum: 1
#
#   ==> DFT Potential <==
#
#    => LibXC <=
#
#     Version 6.1.0
#     S. Lehtola, C. Steigemann, M. J.T. Oliveira, and M. A.L. Marques.,  SoftwareX 7, 1–5 (2018) (10.1016/j.softx.2017.11.002)
#
#    => Composite Functional: CAM-B3LYP <=
#
#     CAM-B3LYP Hyb-GGA Exchange-Correlation Functional
#
#     T. Yanai, D. P. Tew, and N. C. Handy.,  Chem. Phys. Lett. 393, 51 (2004) (10.1016/j.cplett.2004.06.011)
#
#     Deriv               =              1
#     GGA                 =           TRUE
#     Meta                =          FALSE
#
#     Exchange Hybrid     =           TRUE
#     MP2 Hybrid          =          FALSE
#
#    => Exchange Functionals <=
#
#     0.3500         Becke 88 [omega = 0.3300]
#     0.4600   Short-range recipe for B88 functional - erf [omega = 0.3300]
#
#    => Exact (HF) Exchange <=
#
#     0.4600            HF,LR [omega = 0.3300]
#     0.1900               HF
#
#    => Correlation Functionals <=
#
#     0.1900   Vosko, Wilk & Nusair (VWN5)
#     0.8100   Lee, Yang & Parr
#
#    => LibXC Density Thresholds  <==
#
#     XC_HYB_GGA_XC_CAM_B3LYP:  1.00E-14
#
#    => Molecular Quadrature <=
#
#     Radial Scheme          =       TREUTLER
#     Pruning Scheme         =           NONE
#     Nuclear Scheme         =       TREUTLER
#
#     Blocking Scheme        =         OCTREE
#     BS radius alpha        =              1
#     Pruning alpha          =              1
#     Radial Points          =             75
#     Spherical Points       =            302
#     Total Points           =          43148
#     Total Blocks           =            389
#     Max Points             =            256
#     Max Functions          =              6
#     Weights Tolerance      =       1.00E-15
#
#   ==> Integral Setup <==
#
#   Using in-core PK algorithm.
#    Calculation information:
#       Number of atoms:                   2
#       Number of AO shells:               4
#       Number of primitives:             12
#       Number of atomic orbitals:         6
#       Number of basis functions:         6
#
#       Integral cutoff                 1.00e-12
#       Number of threads:                 1
#
#   Performing in-core PK
#   Using 693 doubles for integral storage.
#   We computed 55 shell quartets total.
#   Whereas there are 55 unique shell quartets.
#
#   Computing range-separated integrals for PK
#   We computed 55 wK shell quartets total.
#   Whereas there are 55 wK unique shell quartets.
#
#   ==> DiskJK: Disk-Based J/K Matrices <==
#
#     J tasked:                  Yes
#     K tasked:                  Yes
#     wK tasked:                 Yes
#     Omega:               3.300E-01
#     Memory [MiB]:              367
#     Schwarz Cutoff:          1E-12
#
#     OpenMP threads:              1
#
#   Cached 100.0% of DFT collocation blocks in 0.008 [GiB].
#
#   Minimum eigenvalue in the overlap matrix is 3.2265062182E-01.
#   Reciprocal condition number of the overlap matrix is 1.8831852437E-01.
#     Using symmetric orthogonalization.
#
#   ==> Pre-Iterations <==
#
#   SCF Guess: Superposition of Atomic Densities via on-the-fly atomic UHF (no occupation information).
#
#    -------------------------
#     Irrep   Nso     Nmo
#    -------------------------
#      A          6       6
#    -------------------------
#     Total       6       6
#    -------------------------
#
#   ==> Iterations <==
#
#                         Total Energy        Delta E     RMS |[F,P]|
#
#    @RKS iter SAD:    -7.61705584868900   -7.61706e+00   0.00000e+00
#    @RKS iter   1:    -7.91855701436584   -3.01501e-01   1.97273e-02 ADIIS/DIIS
#    @RKS iter   2:    -7.93637202195207   -1.78150e-02   4.85902e-03 ADIIS/DIIS
#    @RKS iter   3:    -7.93741549084946   -1.04347e-03   4.11591e-04 ADIIS/DIIS
#    @RKS iter   4:    -7.93744885619102   -3.33653e-05   1.06380e-04 ADIIS/DIIS
#    @RKS iter   5:    -7.93745100534132   -2.14915e-06   7.31914e-06 DIIS
#    @RKS iter   6:    -7.93745101245346   -7.11215e-09   4.28956e-08 DIIS
#   Energy and wave function converged.
#
#
#   ==> Post-Iterations <==
#
#    Electrons on quadrature grid:
#       Ntotal   =    4.0000008216 ; deviation = 8.216e-07
#
#     Orbital Energies [Eh]
#     ---------------------
#
#     Doubly Occupied:
#
#        1A     -1.966429     2A     -0.240422
#
#     Virtual:
#
#        3A      0.021323     4A      0.093416     5A      0.093416
#        6A      0.449481
#
#     Final Occupation by Irrep:
#               A
#     DOCC [     2 ]
#     NA   [     2 ]
#     NB   [     2 ]
#
#   @RKS Final Energy:    -7.93745101245346
#
#    => Energetics <=
#
#     Nuclear Repulsion Energy =              1.0504893641325337
#     One-Electron Energy =                 -12.5386948839440873
#     Two-Electron Energy =                   5.0874208088381714
#     DFT Exchange-Correlation Energy =      -1.5366663014800803
#     Empirical Dispersion Energy =           0.0000000000000000
#     VV10 Nonlocal Energy =                  0.0000000000000000
#     Total Energy =                         -7.9374510124534634
#
# Computation Completed
#
#
# Properties will be evaluated at   0.000000,   0.000000,   0.000000 [a0]
#
# Properties computed using the SCF density matrix
#
#
#  Multipole Moments:
#
#  ------------------------------------------------------------------------------------
#      Multipole            Electronic (a.u.)      Nuclear  (a.u.)        Total (a.u.)
#  ------------------------------------------------------------------------------------
#
#  L = 1.  Multiply by 2.5417464519 to convert [e a0] to [Debye]
#  Dipole X            :         -0.0061460            0.0026503           -0.0034958
#  Dipole Y            :          0.0000000            0.0000000            0.0000000
#  Dipole Z            :         -3.2953397            1.4210037           -1.8743360
#  Magnitude           :                                                    1.8743393
#
#  ------------------------------------------------------------------------------------
#
# *** tstop() called on CHEMYM0V4HTALT at Thu Oct 12 13:53:13 2023
# Module time:
# 	user time   =       0.26 seconds =       0.00 minutes
# 	system time =       0.02 seconds =       0.00 minutes
# 	total time  =          0 seconds =       0.00 minutes
# Total time:
# 	user time   =     177.50 seconds =       2.96 minutes
# 	system time =       5.76 seconds =       0.10 minutes
# 	total time  =      80494 seconds =    1341.57 minutes
#
# *** tstart() called on CHEMYM0V4HTALT
# *** at Thu Oct 12 13:53:13 2023
#
#
#          ------------------------------------------------------------
#                                    SCF GRAD
#                           Rob Parrish, Justin Turney,
#                        Andy Simmonett, and Alex Sokolov
#          ------------------------------------------------------------
#
#   ==> Geometry <==
#
#     Molecular point group: c1
#     Full point group: C_inf_v
#
#     Geometry (in Bohr), charge = 0, multiplicity = 1:
#
#        Center              X                  Y                   Z               Mass
#     ------------   -----------------  -----------------  -----------------  -----------------
#          LI          -0.000669001144     0.000000000000    -0.358700799716     7.016003436600
#          H            0.004657271029     0.000000000000     2.497106107741     1.007825032230
#
#   Nuclear repulsion =    1.050489364132534
#
#   ==> Basis Set <==
#
#   Basis Set: STO-3G
#     Blend: STO-3G
#     Number of shells: 4
#     Number of basis functions: 6
#     Number of Cartesian functions: 6
#     Spherical Harmonics?: true
#     Max angular momentum: 1
#
#   ==> DirectJKGrad: Integral-Direct SCF Gradients <==
#
#     Gradient:                    1
#     J tasked:                  Yes
#     K tasked:                  Yes
#     wK tasked:                 Yes
#     Omega:               3.300E-01
#     Integrals threads:           1
#     Schwarz Cutoff:          1E-12
#
#   ==> DFT Potential <==
#
#    => LibXC <=
#
#     Version 6.1.0
#     S. Lehtola, C. Steigemann, M. J.T. Oliveira, and M. A.L. Marques.,  SoftwareX 7, 1–5 (2018) (10.1016/j.softx.2017.11.002)
#
#    => Composite Functional: CAM-B3LYP <=
#
#     CAM-B3LYP Hyb-GGA Exchange-Correlation Functional
#
#     T. Yanai, D. P. Tew, and N. C. Handy.,  Chem. Phys. Lett. 393, 51 (2004) (10.1016/j.cplett.2004.06.011)
#
#     Deriv               =              1
#     GGA                 =           TRUE
#     Meta                =          FALSE
#
#     Exchange Hybrid     =           TRUE
#     MP2 Hybrid          =          FALSE
#
#    => Exchange Functionals <=
#
#     0.3500         Becke 88 [omega = 0.3300]
#     0.4600   Short-range recipe for B88 functional - erf [omega = 0.3300]
#
#    => Exact (HF) Exchange <=
#
#     0.4600            HF,LR [omega = 0.3300]
#     0.1900               HF
#
#    => Correlation Functionals <=
#
#     0.1900   Vosko, Wilk & Nusair (VWN5)
#     0.8100   Lee, Yang & Parr
#
#    => LibXC Density Thresholds  <==
#
#     XC_HYB_GGA_XC_CAM_B3LYP:  1.00E-14
#
#    => Molecular Quadrature <=
#
#     Radial Scheme          =       TREUTLER
#     Pruning Scheme         =           NONE
#     Nuclear Scheme         =       TREUTLER
#
#     Blocking Scheme        =         OCTREE
#     BS radius alpha        =              1
#     Pruning alpha          =              1
#     Radial Points          =             75
#     Spherical Points       =            302
#     Total Points           =          43148
#     Total Blocks           =            389
#     Max Points             =            256
#     Max Functions          =              6
#     Weights Tolerance      =       1.00E-15
#
#
#   -Total Gradient:
#      Atom            X                  Y                   Z
#     ------   -----------------  -----------------  -----------------
#        1        0.000003058973    -0.000000000000     0.001640140759
#        2       -0.000003060604     0.000000000000    -0.001641015533
#
#
# *** tstop() called on CHEMYM0V4HTALT at Thu Oct 12 13:53:13 2023
# Module time:
# 	user time   =       0.04 seconds =       0.00 minutes
# 	system time =       0.00 seconds =       0.00 minutes
# 	total time  =          0 seconds =       0.00 minutes
# Total time:
# 	user time   =     177.54 seconds =       2.96 minutes
# 	system time =       5.76 seconds =       0.10 minutes
# 	total time  =      80494 seconds =    1341.57 minutes
#
#     Psi4 stopped on: Thursday, 12 October 2023 01:53PM
#     Psi4 wall time for execution: 0:00:00.34
#     -----------------------------------------------------------------------
#           Psi4: An Open-Source Ab Initio Electronic Structure Package
#                                Psi4 1.8 release
#
#                          Git: Rev {} zzzzzzz
#
#
#     D. G. A. Smith, L. A. Burns, A. C. Simmonett, R. M. Parrish,
#     M. C. Schieber, R. Galvelis, P. Kraus, H. Kruse, R. Di Remigio,
#     A. Alenaizan, A. M. James, S. Lehtola, J. P. Misiewicz, M. Scheurer,
#     R. A. Shaw, J. B. Schriber, Y. Xie, Z. L. Glick, D. A. Sirianni,
#     J. S. O'Brien, J. M. Waldrop, A. Kumar, E. G. Hohenstein,
#     B. P. Pritchard, B. R. Brooks, H. F. Schaefer III, A. Yu. Sokolov,
#     K. Patkowski, A. E. DePrince III, U. Bozkaya, R. A. King,
#     F. A. Evangelista, J. M. Turney, T. D. Crawford, C. D. Sherrill,
#     J. Chem. Phys. 152(18) 184108 (2020). https://doi.org/10.1063/5.0006002
#
#                             Additional Code Authors
#     E. T. Seidl, C. L. Janssen, E. F. Valeev, M. L. Leininger,
#     J. F. Gonthier, R. M. Richard, H. R. McAlexander, M. Saitow, X. Wang,
#     P. Verma, M. H. Lechner, A. Jiang, S. Behnle, A. G. Heide,
#     M. F. Herbst, and D. L. Poole
#
#              Previous Authors, Complete List of Code Contributors,
#                        and Citations for Specific Modules
#     https://github.com/psi4/psi4/blob/master/codemeta.json
#     https://github.com/psi4/psi4/graphs/contributors
#     http://psicode.org/psi4manual/master/introduction.html#citing-psifour
#
#     -----------------------------------------------------------------------
#
#
#     Psi4 started on: Wednesday, 11 October 2023 03:31PM
#
#     Process ID: 57672
#     Host:       CHEMYM0V4HTALT
#     PSIDATADIR: /Users/ptolley1/miniforge3/envs/work/share/psi4
#     Memory:     500.0 MiB
#     Threads:    1
#
#   ==> Input QCSchema <==
#
# --------------------------------------------------------------------------
# {'driver': 'gradient',
#  'extras': {'psiapi': True, 'wfn_qcvars_only': True},
#  'id': None,
#  'keywords': {'D_CONVERGENCE': 1e-07,
#               'E_CONVERGENCE': 1e-08,
#               'PARENT_SYMMETRY': 'C1',
#               'SAVE_JK': 1,
#               'SCF_TYPE': 'PK',
#               'SCF__INTS_TOLERANCE': 1e-12,
#               'function_kwargs': {'write_orbitals': False}},
#  'model': {'basis': 'sto-3g', 'method': 'cam-b3lyp'},
#  'molecule': {'atom_labels': ['', ''],
#               'atomic_numbers': [3, 1],
#               'fix_com': True,
#               'fix_orientation': True,
#               'fix_symmetry': 'c1',
#               'fragment_charges': [0.0],
#               'fragment_multiplicities': [1],
#               'fragments': [[0, 1]],
#               'geometry': [0.0006690011439782615, 0.0, -0.35870079971559743, -0.0046572710293324455, 0.0,
#                            2.497106107740997],
#               'mass_numbers': [7, 1],
#               'masses': [7.0160034366, 1.00782503223],
#               'molecular_charge': 0.0,
#               'molecular_multiplicity': 1,
#               'name': 'HLi',
#               'provenance': {'creator': 'QCElemental',
#                              'routine': 'qcelemental.molparse.from_string',
#                              'version': 'v0.25.1'},
#               'real': [True, True],
#               'schema_name': 'qcschema_molecule',
#               'schema_version': 2,
#               'symbols': ['Li', 'H'],
#               'validated': True},
#  'protocols': {'stdout': True},
#  'provenance': {'creator': 'QCElemental', 'routine': 'qcelemental.models.results', 'version': 'v0.25.1'},
#  'schema_name': 'qcschema_input',
#  'schema_version': 1}
# --------------------------------------------------------------------------
#
# Scratch directory: /tmp/
# ...
#     0.8100   Lee, Yang & Parr
#
#    => LibXC Density Thresholds  <==
#
#     XC_HYB_GGA_XC_CAM_B3LYP:  1.00E-14
#
#    => Molecular Quadrature <=
#
#     Radial Scheme          =       TREUTLER
#     Pruning Scheme         =           NONE
#     Nuclear Scheme         =       TREUTLER
#
#     Blocking Scheme        =         OCTREE
#     BS radius alpha        =              1
#     Pruning alpha          =              1
#     Radial Points          =             75
#     Spherical Points       =            302
#     Total Points           =          43148
#     Total Blocks           =            398
#     Max Points             =            251
#     Max Functions          =              6
#     Weights Tolerance      =       1.00E-15
#
#   ==> Integral Setup <==
#
#   Using in-core PK algorithm.
#    Calculation information:
#       Number of atoms:                   2
#       Number of AO shells:               4
#       Number of primitives:             12
#       Number of atomic orbitals:         6
#       Number of basis functions:         6
#
#       Integral cutoff                 1.00e-12
#       Number of threads:                 1
#
#   Performing in-core PK
#   Using 693 doubles for integral storage.
#   We computed 55 shell quartets total.
#   Whereas there are 55 unique shell quartets.
#
#   Computing range-separated integrals for PK
#   We computed 55 wK shell quartets total.
#   Whereas there are 55 wK unique shell quartets.
#
#   ==> DiskJK: Disk-Based J/K Matrices <==
#
#     J tasked:                  Yes
#     K tasked:                  Yes
#     wK tasked:                 Yes
#     Omega:               3.300E-01
#     Memory [MiB]:              367
#     Schwarz Cutoff:          1E-12
#
#     OpenMP threads:              1
#
#   Cached 100.0% of DFT collocation blocks in 0.008 [GiB].
#
#   Minimum eigenvalue in the overlap matrix is 3.2191189118E-01.
#   Reciprocal condition number of the overlap matrix is 1.8778642070E-01.
#     Using symmetric orthogonalization.
#
#   ==> Pre-Iterations <==
#
#   SCF Guess: Superposition of Atomic Densities via on-the-fly atomic UHF (no occupation information).
#
#    -------------------------
#     Irrep   Nso     Nmo
#    -------------------------
#      A          6       6
#    -------------------------
#     Total       6       6
#    -------------------------
#
#   ==> Iterations <==
#
#                         Total Energy        Delta E     RMS |[F,P]|
#
#    @RKS iter SAD:    -7.61722999288409   -7.61723e+00   0.00000e+00
#    @RKS iter   1:    -7.91858236340214   -3.01352e-01   1.97194e-02 ADIIS/DIIS
#    @RKS iter   2:    -7.93636855258650   -1.77862e-02   4.84514e-03 ADIIS/DIIS
#    @RKS iter   3:    -7.93740529944495   -1.03675e-03   4.11194e-04 ADIIS/DIIS
#    @RKS iter   4:    -7.93743860404739   -3.33046e-05   1.05619e-04 ADIIS/DIIS
#    @RKS iter   5:    -7.93744072207527   -2.11803e-06   7.27141e-06 DIIS
#    @RKS iter   6:    -7.93744072908869   -7.01341e-09   4.29970e-08 DIIS
#   Energy and wave function converged.
#
#
#   ==> Post-Iterations <==
#
#    Electrons on quadrature grid:
#       Ntotal   =    4.0000008079 ; deviation = 8.079e-07
#
#     Orbital Energies [Eh]
#     ---------------------
#
#     Doubly Occupied:
#
#        1A     -1.966363     2A     -0.240588
#
#     Virtual:
#
#        3A      0.021337     4A      0.093410     5A      0.093410
#        6A      0.450167
#
#     Final Occupation by Irrep:
#               A
#     DOCC [     2 ]
#     NA   [     2 ]
#     NB   [     2 ]
#
#   @RKS Final Energy:    -7.93744072908869
#
#    => Energetics <=
#
#     Nuclear Repulsion Energy =              1.0524540889230973
#     One-Electron Energy =                 -12.5422727370277656
#     Two-Electron Energy =                   5.0892418199265910
#     DFT Exchange-Correlation Energy =      -1.5368639009106106
#     Empirical Dispersion Energy =           0.0000000000000000
#     VV10 Nonlocal Energy =                  0.0000000000000000
#     Total Energy =                         -7.9374407290886877
#
# Computation Completed
#
#
# Properties will be evaluated at   0.000000,   0.000000,   0.000000 [a0]
#
# Properties computed using the SCF density matrix
#
#
#  Multipole Moments:
#
#  ------------------------------------------------------------------------------------
#      Multipole            Electronic (a.u.)      Nuclear  (a.u.)        Total (a.u.)
#  ------------------------------------------------------------------------------------
#
#  L = 1.  Multiply by 2.5417464519 to convert [e a0] to [Debye]
#  Dipole X            :          0.0000000            0.0000000            0.0000000
#  Dipole Y            :         -0.0000000            0.0000000           -0.0000000
#  Dipole Z            :         -3.2926130            1.4183534           -1.8742595
#  Magnitude           :                                                    1.8742595
#
#  ------------------------------------------------------------------------------------
#
# *** tstop() called on CHEMYM0V4HTALT at Thu Oct 12 13:53:15 2023
# Module time:
# 	user time   =       0.27 seconds =       0.00 minutes
# 	system time =       0.01 seconds =       0.00 minutes
# 	total time  =          0 seconds =       0.00 minutes
# Total time:
# 	user time   =     179.17 seconds =       2.99 minutes
# 	system time =       5.84 seconds =       0.10 minutes
# 	total time  =      80496 seconds =    1341.60 minutes
#
# *** tstart() called on CHEMYM0V4HTALT
# *** at Thu Oct 12 13:53:15 2023
#
#
#          ------------------------------------------------------------
#                                    SCF GRAD
#                           Rob Parrish, Justin Turney,
#                        Andy Simmonett, and Alex Sokolov
#          ------------------------------------------------------------
#
#   ==> Geometry <==
#
#     Molecular point group: c1
#     Full point group: C_inf_v
#
#     Geometry (in Bohr), charge = 0, multiplicity = 1:
#
#        Center              X                  Y                   Z               Mass
#     ------------   -----------------  -----------------  -----------------  -----------------
#          LI           0.000000000000     0.000000000000    -0.358031798572     7.016003436600
#          H            0.000000000000     0.000000000000     2.492448836712     1.007825032230
#
#   Nuclear repulsion =    1.052454088923097
#
#   ==> Basis Set <==
#
#   Basis Set: STO-3G
#     Blend: STO-3G
#     Number of shells: 4
#     Number of basis functions: 6
#     Number of Cartesian functions: 6
#     Spherical Harmonics?: true
#     Max angular momentum: 1
#
#   ==> DirectJKGrad: Integral-Direct SCF Gradients <==
#
#     Gradient:                    1
#     J tasked:                  Yes
#     K tasked:                  Yes
#     wK tasked:                 Yes
#     Omega:               3.300E-01
#     Integrals threads:           1
#     Schwarz Cutoff:          1E-12
#
#   ==> DFT Potential <==
#
#    => LibXC <=
#
#     Version 6.1.0
#     S. Lehtola, C. Steigemann, M. J.T. Oliveira, and M. A.L. Marques.,  SoftwareX 7, 1–5 (2018) (10.1016/j.softx.2017.11.002)
#
#    => Composite Functional: CAM-B3LYP <=
#
#     CAM-B3LYP Hyb-GGA Exchange-Correlation Functional
#
#     T. Yanai, D. P. Tew, and N. C. Handy.,  Chem. Phys. Lett. 393, 51 (2004) (10.1016/j.cplett.2004.06.011)
#
#     Deriv               =              1
#     GGA                 =           TRUE
#     Meta                =          FALSE
#
#     Exchange Hybrid     =           TRUE
#     MP2 Hybrid          =          FALSE
#
#    => Exchange Functionals <=
#
#     0.3500         Becke 88 [omega = 0.3300]
#     0.4600   Short-range recipe for B88 functional - erf [omega = 0.3300]
#
#    => Exact (HF) Exchange <=
#
#     0.4600            HF,LR [omega = 0.3300]
#     0.1900               HF
#
#    => Correlation Functionals <=
#
#     0.1900   Vosko, Wilk & Nusair (VWN5)
#     0.8100   Lee, Yang & Parr
#
#    => LibXC Density Thresholds  <==
#
#     XC_HYB_GGA_XC_CAM_B3LYP:  1.00E-14
#
#    => Molecular Quadrature <=
#
#     Radial Scheme          =       TREUTLER
#     Pruning Scheme         =           NONE
#     Nuclear Scheme         =       TREUTLER
#
#     Blocking Scheme        =         OCTREE
#     BS radius alpha        =              1
#     Pruning alpha          =              1
#     Radial Points          =             75
#     Spherical Points       =            302
#     Total Points           =          43148
#     Total Blocks           =            398
#     Max Points             =            251
#     Max Functions          =              6
#     Weights Tolerance      =       1.00E-15
#
#
#   -Total Gradient:
#      Atom            X                  Y                   Z
#     ------   -----------------  -----------------  -----------------
#        1        0.000000000000    -0.000000000000     0.002217057433
#        2        0.000000000000    -0.000000000000    -0.002217888361
#
#
# *** tstop() called on CHEMYM0V4HTALT at Thu Oct 12 13:53:15 2023
# Module time:
# 	user time   =       0.04 seconds =       0.00 minutes
# 	system time =       0.01 seconds =       0.00 minutes
# 	total time  =          0 seconds =       0.00 minutes
# Total time:
# 	user time   =     179.21 seconds =       2.99 minutes
# 	system time =       5.85 seconds =       0.10 minutes
# 	total time  =      80496 seconds =    1341.60 minutes
#
#     Psi4 stopped on: Thursday, 12 October 2023 01:53PM
#     Psi4 wall time for execution: 0:00:00.34
#
#
#   //>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>//
#   //      FiniteDifference Results     //
#   //<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<//
#
#   Computing second-derivative from gradients using projected,
#   symmetry-adapted, cartesian coordinates.
#
#   7 gradients passed in, including the reference geometry.
#   Generating complete list of displacements from unique ones.
#
#
# -------------------------------------------------------------
#
#
#   ==> Harmonic Vibrational Analysis <==
#
#   non-mass-weighted Hessian:       Symmetric? True   Hermitian? True   Lin Dep Dim?  3 (0)
#   projection of translations (True) and rotations (True) removed 5 degrees of freedom (5)
#   total projector:                 Symmetric? True   Hermitian? True   Lin Dep Dim?  5 (5)
#   mass-weighted Hessian:           Symmetric? True   Hermitian? True   Lin Dep Dim?  3 (0)
#   pre-proj  low-frequency mode:    0.0000i [cm^-1]
#   pre-proj  low-frequency mode:    0.0000i [cm^-1]
#   pre-proj  low-frequency mode:    0.0000i [cm^-1]
#   pre-proj  low-frequency mode:    0.0000i [cm^-1]
#   pre-proj  low-frequency mode:    0.0000  [cm^-1]
#   pre-proj  all modes:['131.2608i' '131.2608i' '0.0000i' '0.0000i' '0.0000' '1797.4775']
#   projected mass-weighted Hessian: Symmetric? True   Hermitian? True   Lin Dep Dim?  5 (5)
#   post-proj low-frequency mode:    0.0000i [cm^-1] (TR)
#   post-proj low-frequency mode:    0.0000i [cm^-1] (TR)
#   post-proj low-frequency mode:    0.0000i [cm^-1] (TR)
#   post-proj low-frequency mode:    0.0000  [cm^-1] (TR)
#   post-proj low-frequency mode:    0.0000  [cm^-1] (TR)
#   post-proj  all modes:['0.0000i' '0.0000i' '0.0000i' '0.0000' '0.0000' '1797.4775']
#
#   Vibration                       6
#   Freq [cm^-1]                1797.4775
#   Irrep                           A
#   Reduced mass [u]              1.1293
#   Force const [mDyne/A]         2.1497
#   Turning point v=0 [a0]        0.2435
#   RMS dev v=0 [a0 u^1/2]        0.1830
#   IR activ [km/mol]             0.2524
#   Char temp [K]               2586.1699
#   ----------------------------------------------------------------------------------
#       1   LI               0.00  0.00 -0.14
#       2   H               -0.00 -0.00  0.99
#
#   ==> Thermochemistry Components <==
#
#   Entropy, S
#     Electronic S            0.000 [cal/(mol K)]        0.000 [J/(mol K)]       0.00000000 [mEh/K] (multiplicity = 1)
#     Translational S        32.198 [cal/(mol K)]      134.717 [J/(mol K)]       0.05131102 [mEh/K] (mol. weight = 8.0238 [u], P = 101325.00 [Pa])
#     Rotational S            8.363 [cal/(mol K)]       34.991 [J/(mol K)]       0.01332726 [mEh/K] (symmetry no. = 1)
#     Vibrational S           0.003 [cal/(mol K)]        0.014 [J/(mol K)]       0.00000524 [mEh/K]
#   Total S                  40.564 [cal/(mol K)]      169.722 [J/(mol K)]       0.06464352 [mEh/K]
#   Correction S              0.000 [cal/(mol K)]        0.000 [J/(mol K)]       0.00000000 [mEh/K]
#
#   Constant volume heat capacity, Cv
#     Electronic Cv           0.000 [cal/(mol K)]        0.000 [J/(mol K)]       0.00000000 [mEh/K]
#     Translational Cv        2.981 [cal/(mol K)]       12.472 [J/(mol K)]       0.00475022 [mEh/K]
#     Rotational Cv           1.987 [cal/(mol K)]        8.314 [J/(mol K)]       0.00316681 [mEh/K]
#     Vibrational Cv          0.026 [cal/(mol K)]        0.107 [J/(mol K)]       0.00004075 [mEh/K]
#   Total Cv                  4.994 [cal/(mol K)]       20.893 [J/(mol K)]       0.00795778 [mEh/K]
#   Correction Cv             0.000 [cal/(mol K)]        0.000 [J/(mol K)]       0.00000000 [mEh/K]
#
#   Constant pressure heat capacity, Cp
#     Electronic Cp           0.000 [cal/(mol K)]        0.000 [J/(mol K)]       0.00000000 [mEh/K]
#     Translational Cp        4.968 [cal/(mol K)]       20.786 [J/(mol K)]       0.00791703 [mEh/K]
#     Rotational Cp           1.987 [cal/(mol K)]        8.314 [J/(mol K)]       0.00316681 [mEh/K]
#     Vibrational Cp          0.026 [cal/(mol K)]        0.107 [J/(mol K)]       0.00004075 [mEh/K]
#   Total Cp                  6.981 [cal/(mol K)]       29.208 [J/(mol K)]       0.01112459 [mEh/K]
#   Correction Cp             0.000 [cal/(mol K)]        0.000 [J/(mol K)]       0.00000000 [mEh/K]
#
#   ==> Thermochemistry Energy Analysis <==
#
#   Raw electronic energy, E0
#   Total E0, Electronic energy at well bottom at 0 [K]                   -7.93745100 [Eh]
#
#   Zero-point energy, ZPE_vib = Sum_i nu_i / 2
#     Electronic ZPE          0.000 [kcal/mol]        0.000 [kJ/mol]       0.00000000 [Eh]
#     Translational ZPE       0.000 [kcal/mol]        0.000 [kJ/mol]       0.00000000 [Eh]
#     Rotational ZPE          0.000 [kcal/mol]        0.000 [kJ/mol]       0.00000000 [Eh]
#     Vibrational ZPE         2.570 [kcal/mol]       10.751 [kJ/mol]       0.00409495 [Eh]         898.739 [cm^-1]
#   Correction ZPE            2.570 [kcal/mol]       10.751 [kJ/mol]       0.00409495 [Eh]         898.739 [cm^-1]
#   Total ZPE, Electronic energy at 0 [K]                                 -7.93335605 [Eh]
#
#   Thermal Energy, E (includes ZPE)
#     Electronic E            0.000 [kcal/mol]        0.000 [kJ/mol]       0.00000000 [Eh]
#     Translational E         0.889 [kcal/mol]        3.718 [kJ/mol]       0.00141628 [Eh]
#     Rotational E            0.592 [kcal/mol]        2.479 [kJ/mol]       0.00094418 [Eh]
#     Vibrational E           2.571 [kcal/mol]       10.755 [kJ/mol]       0.00409636 [Eh]
#   Correction E              4.052 [kcal/mol]       16.952 [kJ/mol]       0.00645682 [Eh]
#   Total E, Electronic energy at  298.15 [K]                             -7.93099419 [Eh]
#
#   Enthalpy, H_trans = E_trans + k_B * T
#     Electronic H            0.000 [kcal/mol]        0.000 [kJ/mol]       0.00000000 [Eh]
#     Translational H         1.481 [kcal/mol]        6.197 [kJ/mol]       0.00236046 [Eh]
#     Rotational H            0.592 [kcal/mol]        2.479 [kJ/mol]       0.00094418 [Eh]
#     Vibrational H           2.571 [kcal/mol]       10.755 [kJ/mol]       0.00409636 [Eh]
#   Correction H              4.644 [kcal/mol]       19.431 [kJ/mol]       0.00740100 [Eh]
#   Total H, Enthalpy at  298.15 [K]                                      -7.93005000 [Eh]
#
#   Gibbs free energy, G = H - T * S
#     Electronic G            0.000 [kcal/mol]        0.000 [kJ/mol]       0.00000000 [Eh]
#     Translational G        -8.119 [kcal/mol]      -33.969 [kJ/mol]      -0.01293792 [Eh]
#     Rotational G           -1.901 [kcal/mol]       -7.954 [kJ/mol]      -0.00302934 [Eh]
#     Vibrational G           2.570 [kcal/mol]       10.751 [kJ/mol]       0.00409479 [Eh]
#   Correction G             -7.450 [kcal/mol]      -31.171 [kJ/mol]      -0.01187246 [Eh]
#   Total G, Free enthalpy at  298.15 [K]                                 -7.94932347 [Eh]

# %%
from matplotlib import pyplot as plt

# %% [markdown]
# ## Calculation of the Huang-Rhys Factor
# Huang Rhys factor can be calculated by both
#
# $$ S = 1/2(\Delta x / x_0)^2 \tag{Turner}$$
#
# from the mode anharmonicity paper
#
# and
#
# $$ S = \frac{m\omega_{vib} \Delta x^2}{2 \hbar} \tag{Hsu}$$
#
# from the polaritonic Huang-Rhys factor paper

# %%
# Constants and Variables
x_0 = wfn.frequency_analysis["Xtp0"].data[5]
k = wfn.frequency_analysis["k"].data[5] * 10 ** 2
min_S0_loc = np.argmin(cavity_free_E_array[:,0])
min_S1_loc = np.argmin(cavity_free_E_array[:,1])
delta_au = (r_array[min_S1_loc] - r_array[min_S0_loc]) * 1.8897
delta_m = (r_array[min_S1_loc] - r_array[min_S0_loc]) * 10 ** (-10)
mu_kg = (6.94 * 1.008 / (6.94 + 1.008)) * (10 ** (-3)) / (6.022 * 10 ** 23)
omega_vib = np.sqrt(k / mu_kg)
h_bar = (6.626 * 10 ** (-34)) / (2 * np.pi)

# Turner
S_Turner = 0.5 * (delta_au / x_0) ** 2

# Hsu
S_Hsu = mu_kg * omega_vib * delta_m ** 2 / (2 * h_bar)

print(S_Turner)
print(S_Hsu)
# Out:
# 180.5394412437593
# 159.39380627795506

# %%
var = np.poly1d(cavity_free_E_array[:,0])
derivative = var.deriv()
second_derivative = derivative.deriv()
kappa = second_derivative(r_array[min_S0_loc])
D_e = cavity_free_E_array[49,0]
alpha = kappa / (2 * D_e)
print(alpha)
# Out:
# 2808908558813.629

# %% [markdown]
# First plot the ground-state potential energy surfaces for LiH inside and outisde the cavity.  The effect of the cavity will raise the energy slightly.

# %%
print(cavity_free_E_array[49,0])
# Out:
# -7.784278178707321

# %%
plt.plot(r_array, cavity_free_E_array[:,0], label='cavity free |g>')
plt.plot(r_array, cavity_free_E_array[:,1], 'r-', label='cavity free |e>')
#plt.plot(r_array, cavity_E_array[:,0], label='cavity |g,0>')
plt.legend()
plt.show()

# %% [markdown]
# Next plot the ground state surface shifted by the cavity energy and the first excited state surface of
# LiH outside the cavity along with the lower- and upper-polariton surfaces from LiH inside the cavity.
# Note that lower polariton surface intersects with another surface for the molecule in the cavity (see the crossing of the red and green curves around r = 1.5 Angstroms); the polariton surface is smooth, so we should really re-sort the eigenvalues around this point. Ruby has some experience doing this.

# %%
plt.plot(r_array, cavity_free_E_array[:,0]+0.12086, label='cavity free |g>+$\omega$')
plt.plot(r_array, cavity_free_E_array[:,1], label='cavity free |e>')
plt.plot(r_array, cavity_E_array[:,1], label='cavity |LP>')
plt.plot(r_array, cavity_E_array[:,2], label='cavity |LP>')
plt.plot(r_array, cavity_E_array[:,3], label='cavity |UP>')
plt.legend()
plt.show()
